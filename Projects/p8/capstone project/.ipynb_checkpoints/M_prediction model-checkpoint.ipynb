# %%
#import libraries
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import matplotlib
from matplotlib import pyplot
# %matplotlib inline
import numpy
# Out:
# Using TensorFlow backend.

# %%
import glob
from keras.layers import Dropout

# %%
import pandas as pd
reading_dates=pd.date_range('2011-01-01',freq='W',periods=28)
print(reading_dates)
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-09', '2011-01-16', '2011-01-23',
#                '2011-01-30', '2011-02-06', '2011-02-13', '2011-02-20',
#                '2011-02-27', '2011-03-06', '2011-03-13', '2011-03-20',
#                '2011-03-27', '2011-04-03', '2011-04-10', '2011-04-17',
#                '2011-04-24', '2011-05-01', '2011-05-08', '2011-05-15',
#                '2011-05-22', '2011-05-29', '2011-06-05', '2011-06-12',
#                '2011-06-19', '2011-06-26', '2011-07-03', '2011-07-10'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
path='csv/'
files=glob.glob("csv/*.csv")
data=[]
names=[]
for file in files:
    df=read_csv(file,header=None,names=['Av','Mx_rt','Mn_rt','Avg_rt','th'])
    df['R_dates']=reading_dates
    df=df.set_index('R_dates')
    names.append(file)
    data.append(df)

# %%
values=data[35].values
groups = [0, 1, 4]
i = 1
# plot each column
pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(data[50].columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    #n_in number of lag observations
    #n_out number of next observations
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import LabelEncoder
from numpy import concatenate
#from pandas import DataFrame
#from pandas import concat
#encoder =LabelEncoder()
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
values = data[0].values
    # integer encode direction
    #encoder = LabelEncoder()
    #values[:,4] = encoder.fit_transform(values[:,4])
    # ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
#reframed = series_to_supervised(scaled, 8, 4)
# frame as supervised learning
reframed = series_to_supervised(scaled, 12, 4)
# drop columns we don't want to predict
#reframed.drop(reframed.columns[[5,6,7,8]], axis=1, inplace=True)
print(reframed.head())
# drop columns we don't want to predict
# Out:
#     var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var1(t-11)  \
# 12    0.045455    0.145173    0.248548    0.532258    0.547170    0.022727
# 13    0.022727    0.155122    0.145394    0.483871    0.443397    0.022727
# 14    0.022727    0.020265    0.150456    0.725806    0.688679    0.022727
# 15    0.022727    0.379145    0.078506    0.435484    0.424529    0.000000
# 16    0.000000    0.436625    0.103154    0.661290    0.518868    0.022727
#
#     var2(t-11)  var3(t-11)  var4(t-11)  var5(t-11)    ...      var1(t+2)  \
# 12    0.155122    0.145394    0.483871    0.443397    ...       0.204545
# 13    0.020265    0.150456    0.725806    0.688679    ...       0.204545
# 14    0.379145    0.078506    0.435484    0.424529    ...       0.204545
# 15    0.436625    0.103154    0.661290    0.518868    ...       0.204545
# 16    0.119749    0.139419    0.838710    0.745283    ...       0.272727
#
#     var2(t+2)  var3(t+2)  var4(t+2)  var5(t+2)  var1(t+3)  var2(t+3)  \
# 12   0.380251   0.386639   0.387097   0.339623   0.204545   0.255711
# 13   0.255711   0.141826   0.306452   0.226415   0.204545   0.261238
# 14   0.261238   0.173278   0.354839   0.358490   0.204545   0.413780
# 15   0.413780   0.193942   0.064516   0.000000   0.272727   0.025055
# 16   0.025055   0.548465   0.241935   0.235849   0.204545   0.132277
#
#     var3(t+3)  var4(t+3)  var5(t+3)
# 12   0.141826   0.306452   0.226415
# 13   0.173278   0.354839   0.358490
# 14   0.193942   0.064516   0.000000
# 15   0.548465   0.241935   0.235849
# 16   0.252697   0.322581   0.245283
#
# [5 rows x 80 columns]

# %%
reframed
# Out:
#     var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var1(t-11)  \
# 12    0.045455    0.145173    0.248548    0.532258    0.547170    0.022727
# 13    0.022727    0.155122    0.145394    0.483871    0.443397    0.022727
# 14    0.022727    0.020265    0.150456    0.725806    0.688679    0.022727
# 15    0.022727    0.379145    0.078506    0.435484    0.424529    0.000000
# 16    0.000000    0.436625    0.103154    0.661290    0.518868    0.022727
# 17    0.022727    0.119749    0.139419    0.838710    0.745283    0.045455
# 18    0.045455    0.091747    0.253942    0.274194    0.283019    0.022727
# 19    0.022727    0.109064    0.089295    0.661290    0.537736    0.022727
# 20    0.022727    0.103906    0.096266    0.306452    0.330189    0.022727
# 21    0.022727    0.000000    0.000000    0.129032    0.132076    0.000000
# 22    0.000000    0.315033    0.226307    0.387097    0.283019    0.000000
# 23    0.000000    0.029477    0.096929    0.887097    0.830189    0.250000
# 24    0.250000    0.401990    0.427054    0.096774    0.084906    0.227273
#
#     var2(t-11)  var3(t-11)  var4(t-11)  var5(t-11)    ...      var1(t+2)  \
# 12    0.155122    0.145394    0.483871    0.443397    ...       0.204545
# 13    0.020265    0.150456    0.725806    0.688679    ...       0.204545
# 14    0.379145    0.078506    0.435484    0.424529    ...       0.204545
# 15    0.436625    0.103154    0.661290    0.518868    ...       0.204545
# 16    0.119749    0.139419    0.838710    0.745283    ...       0.272727
# 17    0.091747    0.253942    0.274194    0.283019    ...       0.204545
# 18    0.109064    0.089295    0.661290    0.537736    ...       0.181818
# 19    0.103906    0.096266    0.306452    0.330189    ...       0.204545
# 20    0.000000    0.000000    0.129032    0.132076    ...       1.000000
# 21    0.315033    0.226307    0.387097    0.283019    ...       0.977273
# 22    0.029477    0.096929    0.887097    0.830189    ...       1.000000
# 23    0.401990    0.427054    0.096774    0.084906    ...       1.000000
# 24    0.073692    0.203154    1.000000    1.000000    ...       1.000000
#
#     var2(t+2)  var3(t+2)  var4(t+2)  var5(t+2)  var1(t+3)  var2(t+3)  \
# 12   0.380251   0.386639   0.387097   0.339623   0.204545   0.255711
# 13   0.255711   0.141826   0.306452   0.226415   0.204545   0.261238
# 14   0.261238   0.173278   0.354839   0.358490   0.204545   0.413780
# 15   0.413780   0.193942   0.064516   0.000000   0.272727   0.025055
# 16   0.025055   0.548465   0.241935   0.235849   0.204545   0.132277
# 17   0.132277   0.252697   0.322581   0.245283   0.181818   0.212233
# 18   0.212233   0.269710   0.596774   0.603774   0.204545   0.471629
# 19   0.471629   0.423900   0.096774   0.056604   1.000000   0.190862
# 20   0.190862   0.767137   0.000000   0.009434   0.977273   0.237657
# 21   0.237657   0.594025   0.209677   0.169812   1.000000   0.247237
# 22   0.247237   0.613195   0.338710   0.254717   1.000000   0.612012
# 23   0.612012   0.652282   0.258065   0.254717   1.000000   0.121223
# 24   0.121223   1.000000   0.290323   0.311321   0.977273   1.000000
#
#     var3(t+3)  var4(t+3)  var5(t+3)
# 12   0.141826   0.306452   0.226415
# 13   0.173278   0.354839   0.358490
# 14   0.193942   0.064516   0.000000
# 15   0.548465   0.241935   0.235849
# 16   0.252697   0.322581   0.245283
# 17   0.269710   0.596774   0.603774
# 18   0.423900   0.096774   0.056604
# 19   0.767137   0.000000   0.009434
# 20   0.594025   0.209677   0.169812
# 21   0.613195   0.338710   0.254717
# 22   0.652282   0.258065   0.254717
# 23   1.000000   0.290323   0.311321
# 24   0.843320   0.370968   0.320755
#
# [13 rows x 80 columns]

# %%
preprocessed_data=[]
for i in (range(len(data))):
    values = data[i].values
    # integer encode direction
    #encoder = LabelEncoder()
    #values[:,4] = encoder.fit_transform(values[:,4])
    # ensure all data is float
    values = values.astype('float32')
# normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    reframed = series_to_supervised(scaled,12, 4)
    # drop columns we don't want to predict
    #reframed.drop(reframed.columns[[5,6,7,8]], axis=1, inplace=True)
    preprocessed_data.append(reframed)

# %%
preprocessed_data[0].head()
# Out:
#     var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var1(t-11)  \
# 12    0.045455    0.145173    0.248548    0.532258    0.547170    0.022727
# 13    0.022727    0.155122    0.145394    0.483871    0.443397    0.022727
# 14    0.022727    0.020265    0.150456    0.725806    0.688679    0.022727
# 15    0.022727    0.379145    0.078506    0.435484    0.424529    0.000000
# 16    0.000000    0.436625    0.103154    0.661290    0.518868    0.022727
#
#     var2(t-11)  var3(t-11)  var4(t-11)  var5(t-11)    ...      var1(t+2)  \
# 12    0.155122    0.145394    0.483871    0.443397    ...       0.204545
# 13    0.020265    0.150456    0.725806    0.688679    ...       0.204545
# 14    0.379145    0.078506    0.435484    0.424529    ...       0.204545
# 15    0.436625    0.103154    0.661290    0.518868    ...       0.204545
# 16    0.119749    0.139419    0.838710    0.745283    ...       0.272727
#
#     var2(t+2)  var3(t+2)  var4(t+2)  var5(t+2)  var1(t+3)  var2(t+3)  \
# 12   0.380251   0.386639   0.387097   0.339623   0.204545   0.255711
# 13   0.255711   0.141826   0.306452   0.226415   0.204545   0.261238
# 14   0.261238   0.173278   0.354839   0.358490   0.204545   0.413780
# 15   0.413780   0.193942   0.064516   0.000000   0.272727   0.025055
# 16   0.025055   0.548465   0.241935   0.235849   0.204545   0.132277
#
#     var3(t+3)  var4(t+3)  var5(t+3)
# 12   0.141826   0.306452   0.226415
# 13   0.173278   0.354839   0.358490
# 14   0.193942   0.064516   0.000000
# 15   0.548465   0.241935   0.235849
# 16   0.252697   0.322581   0.245283
#
# [5 rows x 80 columns]

# %%
type(preprocessed_data)
# Out:
# list

# %%
#shape = (2700, 6)

#zeros_array = numpy.zeros(shape)
flatten_data=[]
for sublist in preprocessed_data:
    for item in sublist.values:
        #numpy.append(zeros_array,item)
        #print(type(item))
        #zeros_array.append(item)
        flatten_data.append(item)
flatten_data=numpy.array(flatten_data)

# %%
#import itertools
#flattened_list  = list(itertools.chain(*flat_data))
#x=[l.tolist() for l in flat_data]

# %%
#numpy.array(flat_data)
#type(flat_data)
print(flatten_data)
# Out:
# [[0.0454545  0.14517318 0.24854773 ... 0.14182574 0.3064518  0.22641516]
#  [0.02272725 0.15512161 0.1453942  ... 0.17327803 0.35483885 0.35849047]
#  [0.02272725 0.0202653  0.15045649 ... 0.19394195 0.06451607 0.        ]
#  ...
#  [0.13333333 0.03761206 0.04252559 ... 0.2696761  0.6084656  0.59621453]
#  [0.0666666  0.09964921 0.05056295 ... 0.16432953 0.50264543 0.4921136 ]
#  [0.04999995 0.12439912 0.08253156 ... 0.1449804  0.67724866 0.67192435]]

# %%
print(flatten_data.shape)
import random
random.shuffle(flatten_data)
# Out:
# (1300, 80)

# %%
# split into train and test sets
train = flatten_data[:1170,:]
test = flatten_data[1170:,:]
# split into input and outputs
train_X, train_y = train[:, :60], train[:,60:]
test_X, test_y = test[:, :60], test[:,60:]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 12, 5))
test_X = test_X.reshape((test_X.shape[0], 12, 5))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1170, 12, 5) (1170, 20) (130, 12, 5) (130, 20)

# %%
from keras import regularizers

# %%
# design network
model = Sequential()
model.add(LSTM(60, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True))
model.add(Dropout(0.7))
model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.7))
model.add(Dense(20,activation="relu",activity_regularizer=regularizers.l1(10e-5)))
model.compile(loss='mse', optimizer='adam')  #'mae mse
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 12, 60)            15840
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 12, 60)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 100)               64400
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                2020
# =================================================================
# Total params: 82,260
# Trainable params: 82,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=1500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 1170 samples, validate on 130 samples
# Epoch 1/1500
#  - 5s - loss: 0.2128 - val_loss: 0.1655
# Epoch 2/1500
#  - 1s - loss: 0.1791 - val_loss: 0.1530
# Epoch 3/1500
#  - 1s - loss: 0.1676 - val_loss: 0.1478
# Epoch 4/1500
#  - 1s - loss: 0.1600 - val_loss: 0.1397
# Epoch 5/1500
#  - 1s - loss: 0.1547 - val_loss: 0.1352
# Epoch 6/1500
#  - 1s - loss: 0.1520 - val_loss: 0.1339
# Epoch 7/1500
#  - 1s - loss: 0.1494 - val_loss: 0.1320
# Epoch 8/1500
#  - 1s - loss: 0.1472 - val_loss: 0.1307
# Epoch 9/1500
#  - 1s - loss: 0.1448 - val_loss: 0.1297
# Epoch 10/1500
#  - 1s - loss: 0.1436 - val_loss: 0.1274
# Epoch 11/1500
#  - 1s - loss: 0.1428 - val_loss: 0.1274
# Epoch 12/1500
#  - 1s - loss: 0.1408 - val_loss: 0.1260
# Epoch 13/1500
#  - 1s - loss: 0.1390 - val_loss: 0.1251
# Epoch 14/1500
#  - 1s - loss: 0.1386 - val_loss: 0.1249
# Epoch 15/1500
#  - 1s - loss: 0.1386 - val_loss: 0.1249
# Epoch 16/1500
#  - 1s - loss: 0.1367 - val_loss: 0.1239
# Epoch 17/1500
#  - 1s - loss: 0.1366 - val_loss: 0.1236
# Epoch 18/1500
#  - 1s - loss: 0.1355 - val_loss: 0.1229
# Epoch 19/1500
#  - 1s - loss: 0.1359 - val_loss: 0.1228
# Epoch 20/1500
#  - 1s - loss: 0.1356 - val_loss: 0.1228
# Epoch 21/1500
#  - 1s - loss: 0.1345 - val_loss: 0.1226
# Epoch 22/1500
#  - 1s - loss: 0.1341 - val_loss: 0.1225
# Epoch 23/1500
#  - 1s - loss: 0.1336 - val_loss: 0.1231
# Epoch 24/1500
#  - 1s - loss: 0.1330 - val_loss: 0.1226
# Epoch 25/1500
#  - 1s - loss: 0.1329 - val_loss: 0.1222
# Epoch 26/1500
#  - 1s - loss: 0.1325 - val_loss: 0.1221
# Epoch 27/1500
#  - 1s - loss: 0.1327 - val_loss: 0.1220
# Epoch 28/1500
#  - 1s - loss: 0.1322 - val_loss: 0.1218
# Epoch 29/1500
#  - 1s - loss: 0.1321 - val_loss: 0.1218
# Epoch 30/1500
#  - 1s - loss: 0.1313 - val_loss: 0.1216
# Epoch 31/1500
#  - 1s - loss: 0.1310 - val_loss: 0.1214
# Epoch 32/1500
#  - 1s - loss: 0.1306 - val_loss: 0.1218
# Epoch 33/1500
#  - 1s - loss: 0.1310 - val_loss: 0.1219
# Epoch 34/1500
#  - 1s - loss: 0.1302 - val_loss: 0.1216
# Epoch 35/1500
#  - 1s - loss: 0.1303 - val_loss: 0.1216
# Epoch 36/1500
#  - 1s - loss: 0.1304 - val_loss: 0.1214
# Epoch 37/1500
#  - 1s - loss: 0.1302 - val_loss: 0.1214
# Epoch 38/1500
#  - 1s - loss: 0.1300 - val_loss: 0.1211
# Epoch 39/1500
#  - 1s - loss: 0.1301 - val_loss: 0.1210
# Epoch 40/1500
#  - 1s - loss: 0.1296 - val_loss: 0.1212
# Epoch 41/1500
#  - 1s - loss: 0.1293 - val_loss: 0.1213
# Epoch 42/1500
#  - 1s - loss: 0.1294 - val_loss: 0.1212
# Epoch 43/1500
#  - 1s - loss: 0.1290 - val_loss: 0.1212
# Epoch 44/1500
#  - 1s - loss: 0.1292 - val_loss: 0.1214
# Epoch 45/1500
#  - 2s - loss: 0.1286 - val_loss: 0.1217
# Epoch 46/1500
#  - 1s - loss: 0.1281 - val_loss: 0.1211
# Epoch 47/1500
#  - 1s - loss: 0.1282 - val_loss: 0.1212
# Epoch 48/1500
#  - 1s - loss: 0.1281 - val_loss: 0.1207
# Epoch 49/1500
#  - 1s - loss: 0.1284 - val_loss: 0.1212
# Epoch 50/1500
#  - 1s - loss: 0.1283 - val_loss: 0.1212
# Epoch 51/1500
#  - 1s - loss: 0.1281 - val_loss: 0.1218
# Epoch 52/1500
#  - 1s - loss: 0.1274 - val_loss: 0.1208
# Epoch 53/1500
#  - 1s - loss: 0.1269 - val_loss: 0.1207
# Epoch 54/1500
#  - 1s - loss: 0.1282 - val_loss: 0.1206
# Epoch 55/1500
#  - 1s - loss: 0.1271 - val_loss: 0.1209
# Epoch 56/1500
#  - 1s - loss: 0.1277 - val_loss: 0.1211
# Epoch 57/1500
#  - 1s - loss: 0.1272 - val_loss: 0.1211
# Epoch 58/1500
#  - 1s - loss: 0.1267 - val_loss: 0.1206
# Epoch 59/1500
#  - 1s - loss: 0.1268 - val_loss: 0.1209
# Epoch 60/1500
#  - 1s - loss: 0.1269 - val_loss: 0.1211
# Epoch 61/1500
#  - 1s - loss: 0.1274 - val_loss: 0.1211
# Epoch 62/1500
#  - 1s - loss: 0.1271 - val_loss: 0.1214
# Epoch 63/1500
#  - 1s - loss: 0.1268 - val_loss: 0.1207
# Epoch 64/1500
#  - 1s - loss: 0.1266 - val_loss: 0.1205
# Epoch 65/1500
#  - 1s - loss: 0.1257 - val_loss: 0.1207
# Epoch 66/1500
#  - 1s - loss: 0.1261 - val_loss: 0.1208
# Epoch 67/1500
#  - 1s - loss: 0.1261 - val_loss: 0.1210
# Epoch 68/1500
#  - 1s - loss: 0.1260 - val_loss: 0.1209
# Epoch 69/1500
#  - 1s - loss: 0.1259 - val_loss: 0.1205
# Epoch 70/1500
#  - 1s - loss: 0.1263 - val_loss: 0.1209
# Epoch 71/1500
#  - 1s - loss: 0.1260 - val_loss: 0.1204
# Epoch 72/1500
#  - 1s - loss: 0.1263 - val_loss: 0.1205
# Epoch 73/1500
#  - 1s - loss: 0.1256 - val_loss: 0.1208
# Epoch 74/1500
#  - 1s - loss: 0.1260 - val_loss: 0.1206
# Epoch 75/1500
#  - 1s - loss: 0.1250 - val_loss: 0.1208
# Epoch 76/1500
#  - 1s - loss: 0.1254 - val_loss: 0.1207
# Epoch 77/1500
#  - 1s - loss: 0.1255 - val_loss: 0.1205
# Epoch 78/1500
#  - 1s - loss: 0.1258 - val_loss: 0.1208
# Epoch 79/1500
#  - 1s - loss: 0.1251 - val_loss: 0.1207
# Epoch 80/1500
#  - 1s - loss: 0.1251 - val_loss: 0.1205
# Epoch 81/1500
#  - 1s - loss: 0.1253 - val_loss: 0.1213
# Epoch 82/1500
#  - 1s - loss: 0.1249 - val_loss: 0.1210
# Epoch 83/1500
#  - 1s - loss: 0.1250 - val_loss: 0.1206
# Epoch 84/1500
#  - 1s - loss: 0.1251 - val_loss: 0.1205
# Epoch 85/1500
#  - 1s - loss: 0.1250 - val_loss: 0.1207
# Epoch 86/1500
#  - 1s - loss: 0.1245 - val_loss: 0.1205
# Epoch 87/1500
#  - 1s - loss: 0.1249 - val_loss: 0.1206
# Epoch 88/1500
#  - 1s - loss: 0.1251 - val_loss: 0.1211
# Epoch 89/1500
#  - 1s - loss: 0.1243 - val_loss: 0.1204
# Epoch 90/1500
#  - 1s - loss: 0.1248 - val_loss: 0.1204
# Epoch 91/1500
#  - 1s - loss: 0.1242 - val_loss: 0.1206
# Epoch 92/1500
#  - 1s - loss: 0.1243 - val_loss: 0.1205
# Epoch 93/1500
#  - 1s - loss: 0.1238 - val_loss: 0.1203
# Epoch 94/1500
#  - 1s - loss: 0.1240 - val_loss: 0.1204
# Epoch 95/1500
#  - 1s - loss: 0.1240 - val_loss: 0.1204
# Epoch 96/1500
#  - 1s - loss: 0.1243 - val_loss: 0.1209
# Epoch 97/1500
#  - 1s - loss: 0.1238 - val_loss: 0.1205
# Epoch 98/1500
#  - 1s - loss: 0.1241 - val_loss: 0.1208
# Epoch 99/1500
#  - 1s - loss: 0.1234 - val_loss: 0.1207
# Epoch 100/1500
#  - 1s - loss: 0.1238 - val_loss: 0.1203
# Epoch 101/1500
#  - 1s - loss: 0.1232 - val_loss: 0.1203
# Epoch 102/1500
#  - 1s - loss: 0.1236 - val_loss: 0.1204
# Epoch 103/1500
#  - 1s - loss: 0.1233 - val_loss: 0.1202
# Epoch 104/1500
#  - 1s - loss: 0.1235 - val_loss: 0.1202
# Epoch 105/1500
#  - 1s - loss: 0.1231 - val_loss: 0.1204
# Epoch 106/1500
#  - 1s - loss: 0.1232 - val_loss: 0.1213
# Epoch 107/1500
#  - 1s - loss: 0.1226 - val_loss: 0.1203
# Epoch 108/1500
#  - 1s - loss: 0.1232 - val_loss: 0.1204
# Epoch 109/1500
#  - 1s - loss: 0.1230 - val_loss: 0.1201
# Epoch 110/1500
#  - 1s - loss: 0.1228 - val_loss: 0.1208
# Epoch 111/1500
#  - 1s - loss: 0.1223 - val_loss: 0.1205
# Epoch 112/1500
#  - 1s - loss: 0.1227 - val_loss: 0.1206
# Epoch 113/1500
#  - 1s - loss: 0.1220 - val_loss: 0.1203
# Epoch 114/1500
#  - 1s - loss: 0.1226 - val_loss: 0.1207
# Epoch 115/1500
#  - 1s - loss: 0.1227 - val_loss: 0.1212
# Epoch 116/1500
#  - 1s - loss: 0.1233 - val_loss: 0.1204
# Epoch 117/1500
#  - 1s - loss: 0.1224 - val_loss: 0.1204
# Epoch 118/1500
#  - 1s - loss: 0.1223 - val_loss: 0.1212
# Epoch 119/1500
#  - 1s - loss: 0.1228 - val_loss: 0.1207
# Epoch 120/1500
#  - 1s - loss: 0.1219 - val_loss: 0.1207
# Epoch 121/1500
#  - 1s - loss: 0.1223 - val_loss: 0.1203
# Epoch 122/1500
#  - 1s - loss: 0.1222 - val_loss: 0.1210
# Epoch 123/1500
#  - 1s - loss: 0.1224 - val_loss: 0.1206
# Epoch 124/1500
#  - 1s - loss: 0.1227 - val_loss: 0.1204
# Epoch 125/1500
#  - 1s - loss: 0.1216 - val_loss: 0.1205
# Epoch 126/1500
#  - 1s - loss: 0.1223 - val_loss: 0.1208
# Epoch 127/1500
#  - 1s - loss: 0.1217 - val_loss: 0.1206
# Epoch 128/1500
#  - 1s - loss: 0.1216 - val_loss: 0.1206
# Epoch 129/1500
#  - 1s - loss: 0.1218 - val_loss: 0.1206
# Epoch 130/1500
#  - 1s - loss: 0.1219 - val_loss: 0.1208
# Epoch 131/1500
#  - 1s - loss: 0.1220 - val_loss: 0.1214
# Epoch 132/1500
#  - 1s - loss: 0.1220 - val_loss: 0.1208
# Epoch 133/1500
#  - 1s - loss: 0.1214 - val_loss: 0.1208
# Epoch 134/1500
#  - 1s - loss: 0.1215 - val_loss: 0.1209
# Epoch 135/1500
#  - 1s - loss: 0.1217 - val_loss: 0.1206
# Epoch 136/1500
#  - 1s - loss: 0.1213 - val_loss: 0.1207
# Epoch 137/1500
#  - 1s - loss: 0.1210 - val_loss: 0.1205
# Epoch 138/1500
#  - 1s - loss: 0.1211 - val_loss: 0.1204
# Epoch 139/1500
#  - 1s - loss: 0.1216 - val_loss: 0.1212
# Epoch 140/1500
#  - 1s - loss: 0.1218 - val_loss: 0.1207
# Epoch 141/1500
#  - 1s - loss: 0.1218 - val_loss: 0.1213
# Epoch 142/1500
#  - 1s - loss: 0.1215 - val_loss: 0.1212
# Epoch 143/1500
#  - 1s - loss: 0.1211 - val_loss: 0.1209
# Epoch 144/1500
#  - 1s - loss: 0.1215 - val_loss: 0.1212
# Epoch 145/1500
#  - 1s - loss: 0.1207 - val_loss: 0.1210
# Epoch 146/1500
#  - 1s - loss: 0.1207 - val_loss: 0.1208
# Epoch 147/1500
#  - 1s - loss: 0.1212 - val_loss: 0.1203
# Epoch 148/1500
#  - 1s - loss: 0.1210 - val_loss: 0.1208
# Epoch 149/1500
#  - 1s - loss: 0.1215 - val_loss: 0.1211
# Epoch 150/1500
#  - 1s - loss: 0.1217 - val_loss: 0.1214
# Epoch 151/1500
#  - 1s - loss: 0.1214 - val_loss: 0.1210
# Epoch 152/1500
#  - 1s - loss: 0.1209 - val_loss: 0.1208
# Epoch 153/1500
#  - 1s - loss: 0.1207 - val_loss: 0.1205
# Epoch 154/1500
#  - 1s - loss: 0.1209 - val_loss: 0.1203
# Epoch 155/1500
#  - 1s - loss: 0.1202 - val_loss: 0.1208
# Epoch 156/1500
#  - 1s - loss: 0.1205 - val_loss: 0.1208
# Epoch 157/1500
#  - 1s - loss: 0.1205 - val_loss: 0.1209
# Epoch 158/1500
#  - 1s - loss: 0.1208 - val_loss: 0.1209
# Epoch 159/1500
#  - 1s - loss: 0.1207 - val_loss: 0.1200
# Epoch 160/1500
#  - 1s - loss: 0.1207 - val_loss: 0.1205
# Epoch 161/1500
#  - 1s - loss: 0.1208 - val_loss: 0.1209
# Epoch 162/1500
#  - 1s - loss: 0.1205 - val_loss: 0.1207
# Epoch 163/1500
#  - 1s - loss: 0.1199 - val_loss: 0.1203
# Epoch 164/1500
#  - 1s - loss: 0.1208 - val_loss: 0.1205
# Epoch 165/1500
#  - 1s - loss: 0.1198 - val_loss: 0.1204
# Epoch 166/1500
#  - 1s - loss: 0.1206 - val_loss: 0.1211
# Epoch 167/1500
#  - 1s - loss: 0.1204 - val_loss: 0.1206
# Epoch 168/1500
#  - 1s - loss: 0.1201 - val_loss: 0.1213
# Epoch 169/1500
#  - 1s - loss: 0.1201 - val_loss: 0.1203
# Epoch 170/1500
#  - 1s - loss: 0.1200 - val_loss: 0.1202
# Epoch 171/1500
#  - 1s - loss: 0.1203 - val_loss: 0.1209
# Epoch 172/1500
#  - 1s - loss: 0.1202 - val_loss: 0.1206
# Epoch 173/1500
#  - 1s - loss: 0.1197 - val_loss: 0.1203
# Epoch 174/1500
#  - 1s - loss: 0.1194 - val_loss: 0.1206
# Epoch 175/1500
#  - 1s - loss: 0.1204 - val_loss: 0.1202
# Epoch 176/1500
#  - 1s - loss: 0.1200 - val_loss: 0.1200
# Epoch 177/1500
#  - 1s - loss: 0.1198 - val_loss: 0.1195
# Epoch 178/1500
#  - 1s - loss: 0.1201 - val_loss: 0.1200
# Epoch 179/1500
#  - 1s - loss: 0.1213 - val_loss: 0.1215
# Epoch 180/1500
#  - 1s - loss: 0.1220 - val_loss: 0.1222
# Epoch 181/1500
#  - 1s - loss: 0.1215 - val_loss: 0.1213
# Epoch 182/1500
#  - 1s - loss: 0.1204 - val_loss: 0.1206
# Epoch 183/1500
#  - 1s - loss: 0.1203 - val_loss: 0.1205
# Epoch 184/1500
#  - 1s - loss: 0.1200 - val_loss: 0.1203
# Epoch 185/1500
#  - 1s - loss: 0.1199 - val_loss: 0.1203
# Epoch 186/1500
#  - 1s - loss: 0.1199 - val_loss: 0.1209
# Epoch 187/1500
#  - 1s - loss: 0.1200 - val_loss: 0.1201
# Epoch 188/1500
#  - 1s - loss: 0.1196 - val_loss: 0.1197
# Epoch 189/1500
#  - 1s - loss: 0.1193 - val_loss: 0.1207
# Epoch 190/1500
#  - 1s - loss: 0.1193 - val_loss: 0.1205
# Epoch 191/1500
#  - 1s - loss: 0.1192 - val_loss: 0.1206
# Epoch 192/1500
#  - 1s - loss: 0.1193 - val_loss: 0.1205
# Epoch 193/1500
#  - 1s - loss: 0.1197 - val_loss: 0.1205
# Epoch 194/1500
#  - 1s - loss: 0.1196 - val_loss: 0.1202
# Epoch 195/1500
#  - 1s - loss: 0.1195 - val_loss: 0.1208
# Epoch 196/1500
#  - 1s - loss: 0.1197 - val_loss: 0.1199
# Epoch 197/1500
#  - 1s - loss: 0.1193 - val_loss: 0.1196
# Epoch 198/1500
#  - 1s - loss: 0.1189 - val_loss: 0.1202
# Epoch 199/1500
#  - 1s - loss: 0.1184 - val_loss: 0.1201
# Epoch 200/1500
#  - 1s - loss: 0.1186 - val_loss: 0.1205
# Epoch 201/1500
#  - 1s - loss: 0.1188 - val_loss: 0.1197
# Epoch 202/1500
#  - 1s - loss: 0.1191 - val_loss: 0.1198
# Epoch 203/1500
#  - 1s - loss: 0.1179 - val_loss: 0.1201
# Epoch 204/1500
#  - 1s - loss: 0.1182 - val_loss: 0.1201
# Epoch 205/1500
#  - 1s - loss: 0.1191 - val_loss: 0.1198
# Epoch 206/1500
#  - 1s - loss: 0.1187 - val_loss: 0.1201
# Epoch 207/1500
#  - 1s - loss: 0.1189 - val_loss: 0.1202
# Epoch 208/1500
#  - 1s - loss: 0.1188 - val_loss: 0.1204
# Epoch 209/1500
#  - 1s - loss: 0.1190 - val_loss: 0.1204
# Epoch 210/1500
#  - 1s - loss: 0.1183 - val_loss: 0.1206
# Epoch 211/1500
#  - 1s - loss: 0.1186 - val_loss: 0.1197
# Epoch 212/1500
#  - 1s - loss: 0.1189 - val_loss: 0.1191
# Epoch 213/1500
#  - 1s - loss: 0.1182 - val_loss: 0.1199
# Epoch 214/1500
#  - 1s - loss: 0.1184 - val_loss: 0.1192
# Epoch 215/1500
#  - 1s - loss: 0.1182 - val_loss: 0.1197
# Epoch 216/1500
#  - 1s - loss: 0.1177 - val_loss: 0.1198
# Epoch 217/1500
#  - 1s - loss: 0.1182 - val_loss: 0.1194
# Epoch 218/1500
#  - 1s - loss: 0.1184 - val_loss: 0.1194
# Epoch 219/1500
#  - 1s - loss: 0.1179 - val_loss: 0.1197
# Epoch 220/1500
#  - 1s - loss: 0.1178 - val_loss: 0.1190
# Epoch 221/1500
#  - 1s - loss: 0.1184 - val_loss: 0.1198
# Epoch 222/1500
#  - 1s - loss: 0.1182 - val_loss: 0.1203
# Epoch 223/1500
#  - 1s - loss: 0.1172 - val_loss: 0.1198
# Epoch 224/1500
#  - 1s - loss: 0.1181 - val_loss: 0.1195
# Epoch 225/1500
#  - 1s - loss: 0.1171 - val_loss: 0.1194
# Epoch 226/1500
#  - 1s - loss: 0.1173 - val_loss: 0.1199
# Epoch 227/1500
#  - 1s - loss: 0.1175 - val_loss: 0.1191
# Epoch 228/1500
#  - 1s - loss: 0.1179 - val_loss: 0.1190
# Epoch 229/1500
#  - 1s - loss: 0.1176 - val_loss: 0.1189
# Epoch 230/1500
#  - 1s - loss: 0.1176 - val_loss: 0.1196
# Epoch 231/1500
#  - 1s - loss: 0.1170 - val_loss: 0.1199
# Epoch 232/1500
#  - 1s - loss: 0.1177 - val_loss: 0.1190
# Epoch 233/1500
#  - 1s - loss: 0.1177 - val_loss: 0.1205
# Epoch 234/1500
#  - 1s - loss: 0.1174 - val_loss: 0.1194
# Epoch 235/1500
#  - 1s - loss: 0.1174 - val_loss: 0.1187
# Epoch 236/1500
#  - 1s - loss: 0.1174 - val_loss: 0.1199
# Epoch 237/1500
#  - 1s - loss: 0.1175 - val_loss: 0.1193
# Epoch 238/1500
#  - 1s - loss: 0.1180 - val_loss: 0.1195
# Epoch 239/1500
#  - 1s - loss: 0.1173 - val_loss: 0.1198
# Epoch 240/1500
#  - 1s - loss: 0.1177 - val_loss: 0.1183
# Epoch 241/1500
#  - 1s - loss: 0.1174 - val_loss: 0.1199
# Epoch 242/1500
#  - 1s - loss: 0.1166 - val_loss: 0.1184
# Epoch 243/1500
#  - 1s - loss: 0.1166 - val_loss: 0.1192
# Epoch 244/1500
#  - 1s - loss: 0.1177 - val_loss: 0.1197
# Epoch 245/1500
#  - 1s - loss: 0.1178 - val_loss: 0.1208
# Epoch 246/1500
#  - 1s - loss: 0.1181 - val_loss: 0.1193
# Epoch 247/1500
#  - 1s - loss: 0.1176 - val_loss: 0.1184
# Epoch 248/1500
#  - 1s - loss: 0.1172 - val_loss: 0.1187
# Epoch 249/1500
#  - 1s - loss: 0.1167 - val_loss: 0.1188
# Epoch 250/1500
#  - 1s - loss: 0.1168 - val_loss: 0.1184
# Epoch 251/1500
#  - 1s - loss: 0.1166 - val_loss: 0.1187
# Epoch 252/1500
#  - 1s - loss: 0.1164 - val_loss: 0.1187
# Epoch 253/1500
#  - 1s - loss: 0.1162 - val_loss: 0.1185
# Epoch 254/1500
#  - 1s - loss: 0.1164 - val_loss: 0.1188
# Epoch 255/1500
#  - 1s - loss: 0.1165 - val_loss: 0.1184
# Epoch 256/1500
#  - 1s - loss: 0.1163 - val_loss: 0.1184
# Epoch 257/1500
#  - 1s - loss: 0.1163 - val_loss: 0.1186
# Epoch 258/1500
#  - 1s - loss: 0.1162 - val_loss: 0.1179
# Epoch 259/1500
#  - 1s - loss: 0.1162 - val_loss: 0.1186
# Epoch 260/1500
#  - 1s - loss: 0.1164 - val_loss: 0.1182
# Epoch 261/1500
#  - 1s - loss: 0.1161 - val_loss: 0.1184
# Epoch 262/1500
#  - 1s - loss: 0.1158 - val_loss: 0.1182
# Epoch 263/1500
#  - 1s - loss: 0.1161 - val_loss: 0.1183
# Epoch 264/1500
#  - 1s - loss: 0.1168 - val_loss: 0.1184
# Epoch 265/1500
#  - 1s - loss: 0.1162 - val_loss: 0.1185
# Epoch 266/1500
#  - 1s - loss: 0.1161 - val_loss: 0.1181
# Epoch 267/1500
#  - 1s - loss: 0.1157 - val_loss: 0.1179
# Epoch 268/1500
#  - 1s - loss: 0.1158 - val_loss: 0.1179
# Epoch 269/1500
#  - 1s - loss: 0.1157 - val_loss: 0.1187
# Epoch 270/1500
#  - 1s - loss: 0.1156 - val_loss: 0.1181
# Epoch 271/1500
#  - 1s - loss: 0.1159 - val_loss: 0.1187
# Epoch 272/1500
#  - 2s - loss: 0.1166 - val_loss: 0.1178
# Epoch 273/1500
#  - 1s - loss: 0.1169 - val_loss: 0.1185
# Epoch 274/1500
#  - 1s - loss: 0.1166 - val_loss: 0.1190
# Epoch 275/1500
#  - 2s - loss: 0.1163 - val_loss: 0.1178
# Epoch 276/1500
#  - 2s - loss: 0.1160 - val_loss: 0.1196
# Epoch 277/1500
#  - 2s - loss: 0.1158 - val_loss: 0.1172
# Epoch 278/1500
#  - 2s - loss: 0.1158 - val_loss: 0.1184
# Epoch 279/1500
#  - 1s - loss: 0.1157 - val_loss: 0.1188
# Epoch 280/1500
#  - 1s - loss: 0.1156 - val_loss: 0.1182
# Epoch 281/1500
#  - 1s - loss: 0.1155 - val_loss: 0.1181
# Epoch 282/1500
#  - 1s - loss: 0.1151 - val_loss: 0.1174
# Epoch 283/1500
#  - 1s - loss: 0.1152 - val_loss: 0.1178
# Epoch 284/1500
#  - 1s - loss: 0.1149 - val_loss: 0.1176
# Epoch 285/1500
#  - 1s - loss: 0.1164 - val_loss: 0.1182
# Epoch 286/1500
#  - 1s - loss: 0.1157 - val_loss: 0.1181
# Epoch 287/1500
#  - 1s - loss: 0.1154 - val_loss: 0.1179
# Epoch 288/1500
#  - 1s - loss: 0.1151 - val_loss: 0.1180
# Epoch 289/1500
#  - 1s - loss: 0.1154 - val_loss: 0.1178
# Epoch 290/1500
#  - 1s - loss: 0.1148 - val_loss: 0.1179
# Epoch 291/1500
#  - 1s - loss: 0.1149 - val_loss: 0.1182
# Epoch 292/1500
#  - 1s - loss: 0.1155 - val_loss: 0.1177
# Epoch 293/1500
#  - 1s - loss: 0.1158 - val_loss: 0.1189
# Epoch 294/1500
#  - 1s - loss: 0.1157 - val_loss: 0.1173
# Epoch 295/1500
#  - 1s - loss: 0.1158 - val_loss: 0.1172
# Epoch 296/1500
#  - 1s - loss: 0.1151 - val_loss: 0.1173
# Epoch 297/1500
#  - 1s - loss: 0.1155 - val_loss: 0.1176
# Epoch 298/1500
#  - 1s - loss: 0.1143 - val_loss: 0.1179
# Epoch 299/1500
#  - 1s - loss: 0.1146 - val_loss: 0.1172
# Epoch 300/1500
#  - 1s - loss: 0.1144 - val_loss: 0.1184
# Epoch 301/1500
#  - 1s - loss: 0.1146 - val_loss: 0.1176
# Epoch 302/1500
#  - 1s - loss: 0.1145 - val_loss: 0.1172
# Epoch 303/1500
#  - 1s - loss: 0.1146 - val_loss: 0.1181
# Epoch 304/1500
#  - 1s - loss: 0.1145 - val_loss: 0.1170
# Epoch 305/1500
#  - 1s - loss: 0.1151 - val_loss: 0.1186
# Epoch 306/1500
#  - 1s - loss: 0.1144 - val_loss: 0.1189
# Epoch 307/1500
#  - 1s - loss: 0.1143 - val_loss: 0.1170
# Epoch 308/1500
#  - 1s - loss: 0.1139 - val_loss: 0.1177
# Epoch 309/1500
#  - 1s - loss: 0.1139 - val_loss: 0.1173
# Epoch 310/1500
#  - 1s - loss: 0.1141 - val_loss: 0.1168
# Epoch 311/1500
#  - 1s - loss: 0.1142 - val_loss: 0.1171
# Epoch 312/1500
#  - 1s - loss: 0.1136 - val_loss: 0.1173
# Epoch 313/1500
#  - 1s - loss: 0.1138 - val_loss: 0.1172
# Epoch 314/1500
#  - 1s - loss: 0.1133 - val_loss: 0.1169
# Epoch 315/1500
#  - 1s - loss: 0.1136 - val_loss: 0.1168
# Epoch 316/1500
#  - 2s - loss: 0.1140 - val_loss: 0.1181
# Epoch 317/1500
#  - 1s - loss: 0.1141 - val_loss: 0.1175
# Epoch 318/1500
#  - 1s - loss: 0.1138 - val_loss: 0.1169
# Epoch 319/1500
#  - 1s - loss: 0.1133 - val_loss: 0.1166
# Epoch 320/1500
#  - 1s - loss: 0.1134 - val_loss: 0.1170
# Epoch 321/1500
#  - 1s - loss: 0.1131 - val_loss: 0.1170
# Epoch 322/1500
#  - 1s - loss: 0.1134 - val_loss: 0.1169
# Epoch 323/1500
#  - 1s - loss: 0.1136 - val_loss: 0.1172
# Epoch 324/1500
#  - 1s - loss: 0.1140 - val_loss: 0.1170
# Epoch 325/1500
#  - 1s - loss: 0.1134 - val_loss: 0.1173
# Epoch 326/1500
#  - 1s - loss: 0.1132 - val_loss: 0.1169
# Epoch 327/1500
#  - 1s - loss: 0.1134 - val_loss: 0.1172
# Epoch 328/1500
#  - 1s - loss: 0.1131 - val_loss: 0.1171
# Epoch 329/1500
#  - 1s - loss: 0.1132 - val_loss: 0.1174
# Epoch 330/1500
#  - 1s - loss: 0.1131 - val_loss: 0.1174
# Epoch 331/1500
#  - 1s - loss: 0.1137 - val_loss: 0.1177
# Epoch 332/1500
#  - 2s - loss: 0.1132 - val_loss: 0.1172
# Epoch 333/1500
#  - 1s - loss: 0.1129 - val_loss: 0.1172
# Epoch 334/1500
#  - 1s - loss: 0.1133 - val_loss: 0.1170
# Epoch 335/1500
#  - 1s - loss: 0.1130 - val_loss: 0.1169
# Epoch 336/1500
#  - 2s - loss: 0.1130 - val_loss: 0.1168
# Epoch 337/1500
#  - 2s - loss: 0.1131 - val_loss: 0.1170
# Epoch 338/1500
#  - 1s - loss: 0.1130 - val_loss: 0.1177
# Epoch 339/1500
#  - 1s - loss: 0.1133 - val_loss: 0.1175
# Epoch 340/1500
#  - 1s - loss: 0.1129 - val_loss: 0.1166
# Epoch 341/1500
#  - 1s - loss: 0.1127 - val_loss: 0.1178
# Epoch 342/1500
#  - 1s - loss: 0.1129 - val_loss: 0.1170
# Epoch 343/1500
#  - 1s - loss: 0.1131 - val_loss: 0.1162
# Epoch 344/1500
#  - 1s - loss: 0.1126 - val_loss: 0.1163
# Epoch 345/1500
#  - 1s - loss: 0.1125 - val_loss: 0.1164
# Epoch 346/1500
#  - 1s - loss: 0.1124 - val_loss: 0.1164
# Epoch 347/1500
#  - 1s - loss: 0.1125 - val_loss: 0.1165
# Epoch 348/1500
#  - 1s - loss: 0.1124 - val_loss: 0.1172
# Epoch 349/1500
#  - 1s - loss: 0.1133 - val_loss: 0.1169
# Epoch 350/1500
#  - 1s - loss: 0.1127 - val_loss: 0.1168
# Epoch 351/1500
#  - 1s - loss: 0.1122 - val_loss: 0.1169
# Epoch 352/1500
#  - 1s - loss: 0.1120 - val_loss: 0.1166
# Epoch 353/1500
#  - 1s - loss: 0.1117 - val_loss: 0.1165
# Epoch 354/1500
#  - 1s - loss: 0.1122 - val_loss: 0.1164
# Epoch 355/1500
#  - 1s - loss: 0.1127 - val_loss: 0.1165
# Epoch 356/1500
#  - 1s - loss: 0.1121 - val_loss: 0.1161
# Epoch 357/1500
#  - 1s - loss: 0.1122 - val_loss: 0.1162
# Epoch 358/1500
#  - 1s - loss: 0.1121 - val_loss: 0.1161
# Epoch 359/1500
#  - 1s - loss: 0.1121 - val_loss: 0.1163
# Epoch 360/1500
#  - 1s - loss: 0.1120 - val_loss: 0.1171
# Epoch 361/1500
#  - 1s - loss: 0.1123 - val_loss: 0.1163
# Epoch 362/1500
#  - 1s - loss: 0.1127 - val_loss: 0.1171
# Epoch 363/1500
#  - 1s - loss: 0.1122 - val_loss: 0.1169
# Epoch 364/1500
#  - 1s - loss: 0.1120 - val_loss: 0.1162
# Epoch 365/1500
#  - 1s - loss: 0.1118 - val_loss: 0.1159
# Epoch 366/1500
#  - 1s - loss: 0.1117 - val_loss: 0.1162
# Epoch 367/1500
#  - 1s - loss: 0.1119 - val_loss: 0.1162
# Epoch 368/1500
#  - 2s - loss: 0.1117 - val_loss: 0.1166
# Epoch 369/1500
#  - 2s - loss: 0.1118 - val_loss: 0.1165
# Epoch 370/1500
#  - 2s - loss: 0.1111 - val_loss: 0.1168
# Epoch 371/1500
#  - 1s - loss: 0.1112 - val_loss: 0.1170
# Epoch 372/1500
#  - 1s - loss: 0.1115 - val_loss: 0.1162
# Epoch 373/1500
#  - 1s - loss: 0.1118 - val_loss: 0.1158
# Epoch 374/1500
#  - 2s - loss: 0.1114 - val_loss: 0.1155
# Epoch 375/1500
#  - 1s - loss: 0.1119 - val_loss: 0.1162
# Epoch 376/1500
#  - 1s - loss: 0.1114 - val_loss: 0.1165
# Epoch 377/1500
#  - 1s - loss: 0.1116 - val_loss: 0.1162
# Epoch 378/1500
#  - 1s - loss: 0.1115 - val_loss: 0.1166
# Epoch 379/1500
#  - 1s - loss: 0.1111 - val_loss: 0.1163
# Epoch 380/1500
#  - 1s - loss: 0.1116 - val_loss: 0.1163
# Epoch 381/1500
#  - 1s - loss: 0.1115 - val_loss: 0.1162
# Epoch 382/1500
#  - 1s - loss: 0.1113 - val_loss: 0.1165
# Epoch 383/1500
#  - 1s - loss: 0.1114 - val_loss: 0.1165
# Epoch 384/1500
#  - 1s - loss: 0.1112 - val_loss: 0.1162
# Epoch 385/1500
#  - 1s - loss: 0.1113 - val_loss: 0.1167
# Epoch 386/1500
#  - 1s - loss: 0.1111 - val_loss: 0.1155
# Epoch 387/1500
#  - 1s - loss: 0.1114 - val_loss: 0.1165
# Epoch 388/1500
#  - 1s - loss: 0.1115 - val_loss: 0.1157
# Epoch 389/1500
#  - 1s - loss: 0.1110 - val_loss: 0.1160
# Epoch 390/1500
#  - 3s - loss: 0.1112 - val_loss: 0.1157
# Epoch 391/1500
#  - 1s - loss: 0.1112 - val_loss: 0.1158
# Epoch 392/1500
#  - 1s - loss: 0.1113 - val_loss: 0.1158
# Epoch 393/1500
#  - 1s - loss: 0.1108 - val_loss: 0.1159
# Epoch 394/1500
#  - 1s - loss: 0.1107 - val_loss: 0.1163
# Epoch 395/1500
#  - 1s - loss: 0.1108 - val_loss: 0.1159
# Epoch 396/1500
#  - 1s - loss: 0.1114 - val_loss: 0.1157
# Epoch 397/1500
#  - 1s - loss: 0.1109 - val_loss: 0.1155
# Epoch 398/1500
#  - 1s - loss: 0.1105 - val_loss: 0.1158
# Epoch 399/1500
#  - 1s - loss: 0.1113 - val_loss: 0.1160
# Epoch 400/1500
#  - 1s - loss: 0.1114 - val_loss: 0.1154
# Epoch 401/1500
#  - 1s - loss: 0.1105 - val_loss: 0.1152
# Epoch 402/1500
#  - 1s - loss: 0.1106 - val_loss: 0.1156
# Epoch 403/1500
#  - 1s - loss: 0.1108 - val_loss: 0.1155
# Epoch 404/1500
#  - 1s - loss: 0.1112 - val_loss: 0.1156
# Epoch 405/1500
#  - 1s - loss: 0.1103 - val_loss: 0.1155
# Epoch 406/1500
#  - 1s - loss: 0.1107 - val_loss: 0.1152
# Epoch 407/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1158
# Epoch 408/1500
#  - 1s - loss: 0.1105 - val_loss: 0.1155
# Epoch 409/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1148
# Epoch 410/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1153
# Epoch 411/1500
#  - 1s - loss: 0.1104 - val_loss: 0.1154
# Epoch 412/1500
#  - 1s - loss: 0.1107 - val_loss: 0.1149
# Epoch 413/1500
#  - 1s - loss: 0.1100 - val_loss: 0.1154
# Epoch 414/1500
#  - 1s - loss: 0.1108 - val_loss: 0.1154
# Epoch 415/1500
#  - 1s - loss: 0.1103 - val_loss: 0.1155
# Epoch 416/1500
#  - 1s - loss: 0.1102 - val_loss: 0.1153
# Epoch 417/1500
#  - 2s - loss: 0.1100 - val_loss: 0.1147
# Epoch 418/1500
#  - 1s - loss: 0.1100 - val_loss: 0.1157
# Epoch 419/1500
#  - 1s - loss: 0.1102 - val_loss: 0.1154
# Epoch 420/1500
#  - 2s - loss: 0.1106 - val_loss: 0.1148
# Epoch 421/1500
#  - 1s - loss: 0.1098 - val_loss: 0.1149
# Epoch 422/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1144
# Epoch 423/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1148
# Epoch 424/1500
#  - 1s - loss: 0.1099 - val_loss: 0.1154
# Epoch 425/1500
#  - 1s - loss: 0.1095 - val_loss: 0.1156
# Epoch 426/1500
#  - 2s - loss: 0.1106 - val_loss: 0.1158
# Epoch 427/1500
#  - 1s - loss: 0.1101 - val_loss: 0.1159
# Epoch 428/1500
#  - 2s - loss: 0.1103 - val_loss: 0.1149
# Epoch 429/1500
#  - 2s - loss: 0.1098 - val_loss: 0.1150
# Epoch 430/1500
#  - 1s - loss: 0.1099 - val_loss: 0.1152
# Epoch 431/1500
#  - 1s - loss: 0.1097 - val_loss: 0.1152
# Epoch 432/1500
#  - 1s - loss: 0.1096 - val_loss: 0.1151
# Epoch 433/1500
#  - 1s - loss: 0.1094 - val_loss: 0.1148
# Epoch 434/1500
#  - 1s - loss: 0.1095 - val_loss: 0.1144
# Epoch 435/1500
#  - 1s - loss: 0.1093 - val_loss: 0.1147
# Epoch 436/1500
#  - 1s - loss: 0.1094 - val_loss: 0.1148
# Epoch 437/1500
#  - 1s - loss: 0.1092 - val_loss: 0.1150
# Epoch 438/1500
#  - 1s - loss: 0.1092 - val_loss: 0.1142
# Epoch 439/1500
#  - 1s - loss: 0.1091 - val_loss: 0.1145
# Epoch 440/1500
#  - 1s - loss: 0.1090 - val_loss: 0.1151
# Epoch 441/1500
#  - 1s - loss: 0.1094 - val_loss: 0.1140
# Epoch 442/1500
#  - 1s - loss: 0.1094 - val_loss: 0.1147
# Epoch 443/1500
#  - 1s - loss: 0.1094 - val_loss: 0.1153
# Epoch 444/1500
#  - 1s - loss: 0.1096 - val_loss: 0.1149
# Epoch 445/1500
#  - 1s - loss: 0.1095 - val_loss: 0.1148
# Epoch 446/1500
#  - 1s - loss: 0.1089 - val_loss: 0.1144
# Epoch 447/1500
#  - 1s - loss: 0.1090 - val_loss: 0.1157
# Epoch 448/1500
#  - 1s - loss: 0.1093 - val_loss: 0.1141
# Epoch 449/1500
#  - 1s - loss: 0.1092 - val_loss: 0.1150
# Epoch 450/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1147
# Epoch 451/1500
#  - 1s - loss: 0.1085 - val_loss: 0.1146
# Epoch 452/1500
#  - 1s - loss: 0.1090 - val_loss: 0.1147
# Epoch 453/1500
#  - 2s - loss: 0.1086 - val_loss: 0.1139
# Epoch 454/1500
#  - 2s - loss: 0.1087 - val_loss: 0.1146
# Epoch 455/1500
#  - 2s - loss: 0.1083 - val_loss: 0.1141
# Epoch 456/1500
#  - 1s - loss: 0.1092 - val_loss: 0.1137
# Epoch 457/1500
#  - 1s - loss: 0.1085 - val_loss: 0.1140
# Epoch 458/1500
#  - 1s - loss: 0.1091 - val_loss: 0.1148
# Epoch 459/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1142
# Epoch 460/1500
#  - 1s - loss: 0.1084 - val_loss: 0.1142
# Epoch 461/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1142
# Epoch 462/1500
#  - 1s - loss: 0.1081 - val_loss: 0.1145
# Epoch 463/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1143
# Epoch 464/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1152
# Epoch 465/1500
#  - 1s - loss: 0.1084 - val_loss: 0.1142
# Epoch 466/1500
#  - 1s - loss: 0.1083 - val_loss: 0.1156
# Epoch 467/1500
#  - 1s - loss: 0.1078 - val_loss: 0.1143
# Epoch 468/1500
#  - 1s - loss: 0.1082 - val_loss: 0.1154
# Epoch 469/1500
#  - 1s - loss: 0.1088 - val_loss: 0.1144
# Epoch 470/1500
#  - 1s - loss: 0.1086 - val_loss: 0.1152
# Epoch 471/1500
#  - 1s - loss: 0.1082 - val_loss: 0.1143
# Epoch 472/1500
#  - 1s - loss: 0.1081 - val_loss: 0.1147
# Epoch 473/1500
#  - 1s - loss: 0.1083 - val_loss: 0.1143
# Epoch 474/1500
#  - 1s - loss: 0.1079 - val_loss: 0.1136
# Epoch 475/1500
#  - 1s - loss: 0.1080 - val_loss: 0.1139
# Epoch 476/1500
#  - 1s - loss: 0.1077 - val_loss: 0.1145
# Epoch 477/1500
#  - 1s - loss: 0.1079 - val_loss: 0.1136
# Epoch 478/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1137
# Epoch 479/1500
#  - 1s - loss: 0.1075 - val_loss: 0.1150
# Epoch 480/1500
#  - 1s - loss: 0.1081 - val_loss: 0.1146
# Epoch 481/1500
#  - 1s - loss: 0.1076 - val_loss: 0.1133
# Epoch 482/1500
#  - 1s - loss: 0.1080 - val_loss: 0.1146
# Epoch 483/1500
#  - 1s - loss: 0.1085 - val_loss: 0.1134
# Epoch 484/1500
#  - 1s - loss: 0.1078 - val_loss: 0.1141
# Epoch 485/1500
#  - 1s - loss: 0.1079 - val_loss: 0.1137
# Epoch 486/1500
#  - 1s - loss: 0.1079 - val_loss: 0.1141
# Epoch 487/1500
#  - 1s - loss: 0.1075 - val_loss: 0.1149
# Epoch 488/1500
#  - 1s - loss: 0.1080 - val_loss: 0.1139
# Epoch 489/1500
#  - 1s - loss: 0.1077 - val_loss: 0.1139
# Epoch 490/1500
#  - 1s - loss: 0.1079 - val_loss: 0.1142
# Epoch 491/1500
#  - 1s - loss: 0.1076 - val_loss: 0.1149
# Epoch 492/1500
#  - 1s - loss: 0.1081 - val_loss: 0.1137
# Epoch 493/1500
#  - 1s - loss: 0.1080 - val_loss: 0.1140
# Epoch 494/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1132
# Epoch 495/1500
#  - 1s - loss: 0.1073 - val_loss: 0.1147
# Epoch 496/1500
#  - 1s - loss: 0.1078 - val_loss: 0.1143
# Epoch 497/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1141
# Epoch 498/1500
#  - 1s - loss: 0.1073 - val_loss: 0.1140
# Epoch 499/1500
#  - 1s - loss: 0.1076 - val_loss: 0.1147
# Epoch 500/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1139
# Epoch 501/1500
#  - 1s - loss: 0.1071 - val_loss: 0.1140
# Epoch 502/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1131
# Epoch 503/1500
#  - 1s - loss: 0.1071 - val_loss: 0.1150
# Epoch 504/1500
#  - 1s - loss: 0.1075 - val_loss: 0.1134
# Epoch 505/1500
#  - 2s - loss: 0.1071 - val_loss: 0.1136
# Epoch 506/1500
#  - 2s - loss: 0.1066 - val_loss: 0.1135
# Epoch 507/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1148
# Epoch 508/1500
#  - 2s - loss: 0.1070 - val_loss: 0.1132
# Epoch 509/1500
#  - 1s - loss: 0.1074 - val_loss: 0.1141
# Epoch 510/1500
#  - 1s - loss: 0.1069 - val_loss: 0.1134
# Epoch 511/1500
#  - 1s - loss: 0.1070 - val_loss: 0.1133
# Epoch 512/1500
#  - 1s - loss: 0.1069 - val_loss: 0.1137
# Epoch 513/1500
#  - 1s - loss: 0.1068 - val_loss: 0.1140
# Epoch 514/1500
#  - 1s - loss: 0.1072 - val_loss: 0.1138
# Epoch 515/1500
#  - 1s - loss: 0.1068 - val_loss: 0.1132
# Epoch 516/1500
#  - 1s - loss: 0.1072 - val_loss: 0.1131
# Epoch 517/1500
#  - 1s - loss: 0.1066 - val_loss: 0.1143
# Epoch 518/1500
#  - 1s - loss: 0.1067 - val_loss: 0.1137
# Epoch 519/1500
#  - 1s - loss: 0.1070 - val_loss: 0.1140
# Epoch 520/1500
#  - 1s - loss: 0.1072 - val_loss: 0.1133
# Epoch 521/1500
#  - 1s - loss: 0.1068 - val_loss: 0.1135
# Epoch 522/1500
#  - 1s - loss: 0.1067 - val_loss: 0.1137
# Epoch 523/1500
#  - 1s - loss: 0.1064 - val_loss: 0.1140
# Epoch 524/1500
#  - 1s - loss: 0.1060 - val_loss: 0.1141
# Epoch 525/1500
#  - 1s - loss: 0.1063 - val_loss: 0.1147
# Epoch 526/1500
#  - 1s - loss: 0.1071 - val_loss: 0.1137
# Epoch 527/1500
#  - 1s - loss: 0.1061 - val_loss: 0.1128
# Epoch 528/1500
#  - 1s - loss: 0.1065 - val_loss: 0.1137
# Epoch 529/1500
#  - 1s - loss: 0.1068 - val_loss: 0.1137
# Epoch 530/1500
#  - 1s - loss: 0.1067 - val_loss: 0.1138
# Epoch 531/1500
#  - 1s - loss: 0.1064 - val_loss: 0.1135
# Epoch 532/1500
#  - 1s - loss: 0.1072 - val_loss: 0.1140
# Epoch 533/1500
#  - 1s - loss: 0.1066 - val_loss: 0.1129
# Epoch 534/1500
#  - 1s - loss: 0.1060 - val_loss: 0.1141
# Epoch 535/1500
#  - 1s - loss: 0.1066 - val_loss: 0.1134
# Epoch 536/1500
#  - 1s - loss: 0.1062 - val_loss: 0.1134
# Epoch 537/1500
#  - 1s - loss: 0.1058 - val_loss: 0.1130
# Epoch 538/1500
#  - 1s - loss: 0.1064 - val_loss: 0.1124
# Epoch 539/1500
#  - 1s - loss: 0.1060 - val_loss: 0.1143
# Epoch 540/1500
#  - 1s - loss: 0.1060 - val_loss: 0.1130
# Epoch 541/1500
#  - 1s - loss: 0.1056 - val_loss: 0.1134
# Epoch 542/1500
#  - 1s - loss: 0.1066 - val_loss: 0.1134
# Epoch 543/1500
#  - 1s - loss: 0.1056 - val_loss: 0.1128
# Epoch 544/1500
#  - 1s - loss: 0.1062 - val_loss: 0.1130
# Epoch 545/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1127
# Epoch 546/1500
#  - 1s - loss: 0.1059 - val_loss: 0.1136
# Epoch 547/1500
#  - 1s - loss: 0.1056 - val_loss: 0.1130
# Epoch 548/1500
#  - 1s - loss: 0.1053 - val_loss: 0.1132
# Epoch 549/1500
#  - 1s - loss: 0.1057 - val_loss: 0.1130
# Epoch 550/1500
#  - 1s - loss: 0.1053 - val_loss: 0.1130
# Epoch 551/1500
#  - 1s - loss: 0.1050 - val_loss: 0.1134
# Epoch 552/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1129
# Epoch 553/1500
#  - 1s - loss: 0.1059 - val_loss: 0.1131
# Epoch 554/1500
#  - 1s - loss: 0.1059 - val_loss: 0.1133
# Epoch 555/1500
#  - 1s - loss: 0.1056 - val_loss: 0.1138
# Epoch 556/1500
#  - 2s - loss: 0.1054 - val_loss: 0.1128
# Epoch 557/1500
#  - 1s - loss: 0.1057 - val_loss: 0.1121
# Epoch 558/1500
#  - 1s - loss: 0.1053 - val_loss: 0.1134
# Epoch 559/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1136
# Epoch 560/1500
#  - 1s - loss: 0.1051 - val_loss: 0.1128
# Epoch 561/1500
#  - 1s - loss: 0.1050 - val_loss: 0.1139
# Epoch 562/1500
#  - 2s - loss: 0.1051 - val_loss: 0.1132
# Epoch 563/1500
#  - 1s - loss: 0.1055 - val_loss: 0.1125
# Epoch 564/1500
#  - 1s - loss: 0.1056 - val_loss: 0.1128
# Epoch 565/1500
#  - 2s - loss: 0.1050 - val_loss: 0.1145
# Epoch 566/1500
#  - 1s - loss: 0.1051 - val_loss: 0.1142
# Epoch 567/1500
#  - 1s - loss: 0.1053 - val_loss: 0.1135
# Epoch 568/1500
#  - 1s - loss: 0.1051 - val_loss: 0.1125
# Epoch 569/1500
#  - 1s - loss: 0.1055 - val_loss: 0.1139
# Epoch 570/1500
#  - 1s - loss: 0.1058 - val_loss: 0.1128
# Epoch 571/1500
#  - 1s - loss: 0.1052 - val_loss: 0.1131
# Epoch 572/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1119
# Epoch 573/1500
#  - 1s - loss: 0.1047 - val_loss: 0.1134
# Epoch 574/1500
#  - 1s - loss: 0.1048 - val_loss: 0.1125
# Epoch 575/1500
#  - 1s - loss: 0.1051 - val_loss: 0.1130
# Epoch 576/1500
#  - 1s - loss: 0.1045 - val_loss: 0.1135
# Epoch 577/1500
#  - 1s - loss: 0.1045 - val_loss: 0.1125
# Epoch 578/1500
#  - 1s - loss: 0.1053 - val_loss: 0.1128
# Epoch 579/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1121
# Epoch 580/1500
#  - 1s - loss: 0.1047 - val_loss: 0.1125
# Epoch 581/1500
#  - 1s - loss: 0.1042 - val_loss: 0.1130
# Epoch 582/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1132
# Epoch 583/1500
#  - 1s - loss: 0.1052 - val_loss: 0.1130
# Epoch 584/1500
#  - 1s - loss: 0.1046 - val_loss: 0.1136
# Epoch 585/1500
#  - 1s - loss: 0.1048 - val_loss: 0.1119
# Epoch 586/1500
#  - 1s - loss: 0.1054 - val_loss: 0.1136
# Epoch 587/1500
#  - 1s - loss: 0.1046 - val_loss: 0.1122
# Epoch 588/1500
#  - 1s - loss: 0.1048 - val_loss: 0.1118
# Epoch 589/1500
#  - 1s - loss: 0.1039 - val_loss: 0.1128
# Epoch 590/1500
#  - 1s - loss: 0.1041 - val_loss: 0.1128
# Epoch 591/1500
#  - 1s - loss: 0.1046 - val_loss: 0.1120
# Epoch 592/1500
#  - 1s - loss: 0.1041 - val_loss: 0.1137
# Epoch 593/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1124
# Epoch 594/1500
#  - 1s - loss: 0.1039 - val_loss: 0.1133
# Epoch 595/1500
#  - 1s - loss: 0.1044 - val_loss: 0.1124
# Epoch 596/1500
#  - 1s - loss: 0.1038 - val_loss: 0.1132
# Epoch 597/1500
#  - 1s - loss: 0.1045 - val_loss: 0.1126
# Epoch 598/1500
#  - 1s - loss: 0.1045 - val_loss: 0.1137
# Epoch 599/1500
#  - 1s - loss: 0.1042 - val_loss: 0.1127
# Epoch 600/1500
#  - 1s - loss: 0.1046 - val_loss: 0.1126
# Epoch 601/1500
#  - 1s - loss: 0.1043 - val_loss: 0.1123
# Epoch 602/1500
#  - 1s - loss: 0.1048 - val_loss: 0.1129
# Epoch 603/1500
#  - 1s - loss: 0.1039 - val_loss: 0.1127
# Epoch 604/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1129
# Epoch 605/1500
#  - 1s - loss: 0.1043 - val_loss: 0.1133
# Epoch 606/1500
#  - 1s - loss: 0.1043 - val_loss: 0.1138
# Epoch 607/1500
#  - 1s - loss: 0.1038 - val_loss: 0.1126
# Epoch 608/1500
#  - 1s - loss: 0.1038 - val_loss: 0.1122
# Epoch 609/1500
#  - 1s - loss: 0.1034 - val_loss: 0.1125
# Epoch 610/1500
#  - 1s - loss: 0.1037 - val_loss: 0.1137
# Epoch 611/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1122
# Epoch 612/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1130
# Epoch 613/1500
#  - 1s - loss: 0.1034 - val_loss: 0.1126
# Epoch 614/1500
#  - 1s - loss: 0.1036 - val_loss: 0.1135
# Epoch 615/1500
#  - 1s - loss: 0.1038 - val_loss: 0.1119
# Epoch 616/1500
#  - 1s - loss: 0.1038 - val_loss: 0.1128
# Epoch 617/1500
#  - 1s - loss: 0.1037 - val_loss: 0.1128
# Epoch 618/1500
#  - 1s - loss: 0.1033 - val_loss: 0.1115
# Epoch 619/1500
#  - 1s - loss: 0.1033 - val_loss: 0.1135
# Epoch 620/1500
#  - 1s - loss: 0.1039 - val_loss: 0.1132
# Epoch 621/1500
#  - 1s - loss: 0.1039 - val_loss: 0.1128
# Epoch 622/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1125
# Epoch 623/1500
#  - 1s - loss: 0.1036 - val_loss: 0.1124
# Epoch 624/1500
#  - 1s - loss: 0.1040 - val_loss: 0.1132
# Epoch 625/1500
#  - 1s - loss: 0.1033 - val_loss: 0.1117
# Epoch 626/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1128
# Epoch 627/1500
#  - 1s - loss: 0.1035 - val_loss: 0.1130
# Epoch 628/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1138
# Epoch 629/1500
#  - 1s - loss: 0.1035 - val_loss: 0.1117
# Epoch 630/1500
#  - 1s - loss: 0.1035 - val_loss: 0.1135
# Epoch 631/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1126
# Epoch 632/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1121
# Epoch 633/1500
#  - 1s - loss: 0.1030 - val_loss: 0.1125
# Epoch 634/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1121
# Epoch 635/1500
#  - 1s - loss: 0.1027 - val_loss: 0.1135
# Epoch 636/1500
#  - 2s - loss: 0.1030 - val_loss: 0.1123
# Epoch 637/1500
#  - 2s - loss: 0.1030 - val_loss: 0.1132
# Epoch 638/1500
#  - 1s - loss: 0.1028 - val_loss: 0.1121
# Epoch 639/1500
#  - 1s - loss: 0.1028 - val_loss: 0.1127
# Epoch 640/1500
#  - 1s - loss: 0.1033 - val_loss: 0.1124
# Epoch 641/1500
#  - 1s - loss: 0.1025 - val_loss: 0.1127
# Epoch 642/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1118
# Epoch 643/1500
#  - 1s - loss: 0.1025 - val_loss: 0.1134
# Epoch 644/1500
#  - 1s - loss: 0.1030 - val_loss: 0.1139
# Epoch 645/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1134
# Epoch 646/1500
#  - 1s - loss: 0.1027 - val_loss: 0.1128
# Epoch 647/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1128
# Epoch 648/1500
#  - 1s - loss: 0.1023 - val_loss: 0.1129
# Epoch 649/1500
#  - 1s - loss: 0.1030 - val_loss: 0.1128
# Epoch 650/1500
#  - 1s - loss: 0.1024 - val_loss: 0.1127
# Epoch 651/1500
#  - 1s - loss: 0.1025 - val_loss: 0.1125
# Epoch 652/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1135
# Epoch 653/1500
#  - 1s - loss: 0.1021 - val_loss: 0.1132
# Epoch 654/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1126
# Epoch 655/1500
#  - 1s - loss: 0.1023 - val_loss: 0.1147
# Epoch 656/1500
#  - 1s - loss: 0.1030 - val_loss: 0.1128
# Epoch 657/1500
#  - 1s - loss: 0.1025 - val_loss: 0.1132
# Epoch 658/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1126
# Epoch 659/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1134
# Epoch 660/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1134
# Epoch 661/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1129
# Epoch 662/1500
#  - 1s - loss: 0.1021 - val_loss: 0.1125
# Epoch 663/1500
#  - 1s - loss: 0.1023 - val_loss: 0.1133
# Epoch 664/1500
#  - 1s - loss: 0.1031 - val_loss: 0.1133
# Epoch 665/1500
#  - 1s - loss: 0.1026 - val_loss: 0.1135
# Epoch 666/1500
#  - 1s - loss: 0.1022 - val_loss: 0.1125
# Epoch 667/1500
#  - 1s - loss: 0.1020 - val_loss: 0.1129
# Epoch 668/1500
#  - 1s - loss: 0.1017 - val_loss: 0.1130
# Epoch 669/1500
#  - 1s - loss: 0.1025 - val_loss: 0.1129
# Epoch 670/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1137
# Epoch 671/1500
#  - 1s - loss: 0.1023 - val_loss: 0.1136
# Epoch 672/1500
#  - 1s - loss: 0.1021 - val_loss: 0.1137
# Epoch 673/1500
#  - 1s - loss: 0.1020 - val_loss: 0.1131
# Epoch 674/1500
#  - 1s - loss: 0.1017 - val_loss: 0.1143
# Epoch 675/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1142
# Epoch 676/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1140
# Epoch 677/1500
#  - 1s - loss: 0.1020 - val_loss: 0.1127
# Epoch 678/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1135
# Epoch 679/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1133
# Epoch 680/1500
#  - 1s - loss: 0.1015 - val_loss: 0.1144
# Epoch 681/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1130
# Epoch 682/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1132
# Epoch 683/1500
#  - 1s - loss: 0.1013 - val_loss: 0.1134
# Epoch 684/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1138
# Epoch 685/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1124
# Epoch 686/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1142
# Epoch 687/1500
#  - 1s - loss: 0.1021 - val_loss: 0.1134
# Epoch 688/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1130
# Epoch 689/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1131
# Epoch 690/1500
#  - 1s - loss: 0.1014 - val_loss: 0.1130
# Epoch 691/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1136
# Epoch 692/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1134
# Epoch 693/1500
#  - 1s - loss: 0.1018 - val_loss: 0.1127
# Epoch 694/1500
#  - 1s - loss: 0.1019 - val_loss: 0.1136
# Epoch 695/1500
#  - 1s - loss: 0.1015 - val_loss: 0.1135
# Epoch 696/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1130
# Epoch 697/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1132
# Epoch 698/1500
#  - 1s - loss: 0.1012 - val_loss: 0.1140
# Epoch 699/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1122
# Epoch 700/1500
#  - 1s - loss: 0.1015 - val_loss: 0.1131
# Epoch 701/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1132
# Epoch 702/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1129
# Epoch 703/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1139
# Epoch 704/1500
#  - 1s - loss: 0.1011 - val_loss: 0.1131
# Epoch 705/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1135
# Epoch 706/1500
#  - 1s - loss: 0.1013 - val_loss: 0.1141
# Epoch 707/1500
#  - 1s - loss: 0.1013 - val_loss: 0.1132
# Epoch 708/1500
#  - 1s - loss: 0.1011 - val_loss: 0.1146
# Epoch 709/1500
#  - 1s - loss: 0.1016 - val_loss: 0.1130
# Epoch 710/1500
#  - 1s - loss: 0.1014 - val_loss: 0.1143
# Epoch 711/1500
#  - 1s - loss: 0.1003 - val_loss: 0.1134
# Epoch 712/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1137
# Epoch 713/1500
#  - 1s - loss: 0.1011 - val_loss: 0.1131
# Epoch 714/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1126
# Epoch 715/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1130
# Epoch 716/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1126
# Epoch 717/1500
#  - 1s - loss: 0.1007 - val_loss: 0.1137
# Epoch 718/1500
#  - 1s - loss: 0.1008 - val_loss: 0.1129
# Epoch 719/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1131
# Epoch 720/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1124
# Epoch 721/1500
#  - 1s - loss: 0.1008 - val_loss: 0.1136
# Epoch 722/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1124
# Epoch 723/1500
#  - 1s - loss: 0.1007 - val_loss: 0.1129
# Epoch 724/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1140
# Epoch 725/1500
#  - 1s - loss: 0.1007 - val_loss: 0.1140
# Epoch 726/1500
#  - 1s - loss: 0.1005 - val_loss: 0.1137
# Epoch 727/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1136
# Epoch 728/1500
#  - 1s - loss: 0.1006 - val_loss: 0.1123
# Epoch 729/1500
#  - 1s - loss: 0.1004 - val_loss: 0.1132
# Epoch 730/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1132
# Epoch 731/1500
#  - 1s - loss: 0.1011 - val_loss: 0.1128
# Epoch 732/1500
#  - 1s - loss: 0.1012 - val_loss: 0.1141
# Epoch 733/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1130
# Epoch 734/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1124
# Epoch 735/1500
#  - 1s - loss: 0.1008 - val_loss: 0.1151
# Epoch 736/1500
#  - 1s - loss: 0.1008 - val_loss: 0.1136
# Epoch 737/1500
#  - 1s - loss: 0.1006 - val_loss: 0.1137
# Epoch 738/1500
#  - 1s - loss: 0.1000 - val_loss: 0.1132
# Epoch 739/1500
#  - 1s - loss: 0.1008 - val_loss: 0.1134
# Epoch 740/1500
#  - 1s - loss: 0.1010 - val_loss: 0.1126
# Epoch 741/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1141
# Epoch 742/1500
#  - 1s - loss: 0.1005 - val_loss: 0.1138
# Epoch 743/1500
#  - 1s - loss: 0.1004 - val_loss: 0.1135
# Epoch 744/1500
#  - 1s - loss: 0.1004 - val_loss: 0.1128
# Epoch 745/1500
#  - 1s - loss: 0.1002 - val_loss: 0.1135
# Epoch 746/1500
#  - 1s - loss: 0.1003 - val_loss: 0.1128
# Epoch 747/1500
#  - 1s - loss: 0.1005 - val_loss: 0.1143
# Epoch 748/1500
#  - 1s - loss: 0.1009 - val_loss: 0.1142
# Epoch 749/1500
#  - 1s - loss: 0.0998 - val_loss: 0.1129
# Epoch 750/1500
#  - 1s - loss: 0.1000 - val_loss: 0.1133
# Epoch 751/1500
#  - 1s - loss: 0.0999 - val_loss: 0.1126
# Epoch 752/1500
#  - 1s - loss: 0.1000 - val_loss: 0.1135
# Epoch 753/1500
#  - 1s - loss: 0.0997 - val_loss: 0.1137
# Epoch 754/1500
#  - 1s - loss: 0.1000 - val_loss: 0.1142
# Epoch 755/1500
#  - 1s - loss: 0.1003 - val_loss: 0.1128
# Epoch 756/1500
#  - 1s - loss: 0.1002 - val_loss: 0.1134
# Epoch 757/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1138
# Epoch 758/1500
#  - 1s - loss: 0.1004 - val_loss: 0.1148
# Epoch 759/1500
#  - 1s - loss: 0.1004 - val_loss: 0.1135
# Epoch 760/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1137
# Epoch 761/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1132
# Epoch 762/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1135
# Epoch 763/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1141
# Epoch 764/1500
#  - 1s - loss: 0.0999 - val_loss: 0.1136
# Epoch 765/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1147
# Epoch 766/1500
#  - 1s - loss: 0.0993 - val_loss: 0.1134
# Epoch 767/1500
#  - 1s - loss: 0.1003 - val_loss: 0.1144
# Epoch 768/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1138
# Epoch 769/1500
#  - 1s - loss: 0.0998 - val_loss: 0.1139
# Epoch 770/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1140
# Epoch 771/1500
#  - 1s - loss: 0.0998 - val_loss: 0.1133
# Epoch 772/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1144
# Epoch 773/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1148
# Epoch 774/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1145
# Epoch 775/1500
#  - 1s - loss: 0.0998 - val_loss: 0.1135
# Epoch 776/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1132
# Epoch 777/1500
#  - 1s - loss: 0.0992 - val_loss: 0.1141
# Epoch 778/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1148
# Epoch 779/1500
#  - 1s - loss: 0.1001 - val_loss: 0.1131
# Epoch 780/1500
#  - 1s - loss: 0.1000 - val_loss: 0.1129
# Epoch 781/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1134
# Epoch 782/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1143
# Epoch 783/1500
#  - 1s - loss: 0.0998 - val_loss: 0.1129
# Epoch 784/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1139
# Epoch 785/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1134
# Epoch 786/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1146
# Epoch 787/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1144
# Epoch 788/1500
#  - 1s - loss: 0.0997 - val_loss: 0.1133
# Epoch 789/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1134
# Epoch 790/1500
#  - 1s - loss: 0.0993 - val_loss: 0.1134
# Epoch 791/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1140
# Epoch 792/1500
#  - 2s - loss: 0.0993 - val_loss: 0.1132
# Epoch 793/1500
#  - 2s - loss: 0.0990 - val_loss: 0.1141
# Epoch 794/1500
#  - 2s - loss: 0.0994 - val_loss: 0.1141
# Epoch 795/1500
#  - 2s - loss: 0.0996 - val_loss: 0.1139
# Epoch 796/1500
#  - 2s - loss: 0.0997 - val_loss: 0.1149
# Epoch 797/1500
#  - 2s - loss: 0.0996 - val_loss: 0.1144
# Epoch 798/1500
#  - 2s - loss: 0.0993 - val_loss: 0.1134
# Epoch 799/1500
#  - 1s - loss: 0.0997 - val_loss: 0.1132
# Epoch 800/1500
#  - 1s - loss: 0.0993 - val_loss: 0.1139
# Epoch 801/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1137
# Epoch 802/1500
#  - 1s - loss: 0.0988 - val_loss: 0.1128
# Epoch 803/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1140
# Epoch 804/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1140
# Epoch 805/1500
#  - 1s - loss: 0.0992 - val_loss: 0.1143
# Epoch 806/1500
#  - 1s - loss: 0.0996 - val_loss: 0.1138
# Epoch 807/1500
#  - 1s - loss: 0.0992 - val_loss: 0.1134
# Epoch 808/1500
#  - 1s - loss: 0.0992 - val_loss: 0.1133
# Epoch 809/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1129
# Epoch 810/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1133
# Epoch 811/1500
#  - 1s - loss: 0.0994 - val_loss: 0.1138
# Epoch 812/1500
#  - 1s - loss: 0.0992 - val_loss: 0.1140
# Epoch 813/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1135
# Epoch 814/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1143
# Epoch 815/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1134
# Epoch 816/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1131
# Epoch 817/1500
#  - 1s - loss: 0.0990 - val_loss: 0.1134
# Epoch 818/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1143
# Epoch 819/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1135
# Epoch 820/1500
#  - 1s - loss: 0.0985 - val_loss: 0.1134
# Epoch 821/1500
#  - 1s - loss: 0.0986 - val_loss: 0.1127
# Epoch 822/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1119
# Epoch 823/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1132
# Epoch 824/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1136
# Epoch 825/1500
#  - 1s - loss: 0.0988 - val_loss: 0.1141
# Epoch 826/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1138
# Epoch 827/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1144
# Epoch 828/1500
#  - 1s - loss: 0.0995 - val_loss: 0.1131
# Epoch 829/1500
#  - 1s - loss: 0.0989 - val_loss: 0.1143
# Epoch 830/1500
#  - 1s - loss: 0.0985 - val_loss: 0.1133
# Epoch 831/1500
#  - 1s - loss: 0.0986 - val_loss: 0.1133
# Epoch 832/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1132
# Epoch 833/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1131
# Epoch 834/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1142
# Epoch 835/1500
#  - 1s - loss: 0.0981 - val_loss: 0.1136
# Epoch 836/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1128
# Epoch 837/1500
#  - 1s - loss: 0.0981 - val_loss: 0.1137
# Epoch 838/1500
#  - 1s - loss: 0.0986 - val_loss: 0.1123
# Epoch 839/1500
#  - 1s - loss: 0.0986 - val_loss: 0.1137
# Epoch 840/1500
#  - 1s - loss: 0.0991 - val_loss: 0.1137
# Epoch 841/1500
#  - 1s - loss: 0.0986 - val_loss: 0.1138
# Epoch 842/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1133
# Epoch 843/1500
#  - 1s - loss: 0.0975 - val_loss: 0.1149
# Epoch 844/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1136
# Epoch 845/1500
#  - 1s - loss: 0.0978 - val_loss: 0.1133
# Epoch 846/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1133
# Epoch 847/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1140
# Epoch 848/1500
#  - 1s - loss: 0.0979 - val_loss: 0.1135
# Epoch 849/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1137
# Epoch 850/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1130
# Epoch 851/1500
#  - 1s - loss: 0.0980 - val_loss: 0.1139
# Epoch 852/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1142
# Epoch 853/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1136
# Epoch 854/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1139
# Epoch 855/1500
#  - 1s - loss: 0.0979 - val_loss: 0.1129
# Epoch 856/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1136
# Epoch 857/1500
#  - 1s - loss: 0.0985 - val_loss: 0.1141
# Epoch 858/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1145
# Epoch 859/1500
#  - 1s - loss: 0.0978 - val_loss: 0.1135
# Epoch 860/1500
#  - 1s - loss: 0.0985 - val_loss: 0.1142
# Epoch 861/1500
#  - 1s - loss: 0.0985 - val_loss: 0.1144
# Epoch 862/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1145
# Epoch 863/1500
#  - 1s - loss: 0.0987 - val_loss: 0.1148
# Epoch 864/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1139
# Epoch 865/1500
#  - 1s - loss: 0.0981 - val_loss: 0.1151
# Epoch 866/1500
#  - 1s - loss: 0.0981 - val_loss: 0.1134
# Epoch 867/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1152
# Epoch 868/1500
#  - 1s - loss: 0.0979 - val_loss: 0.1135
# Epoch 869/1500
#  - 1s - loss: 0.0984 - val_loss: 0.1125
# Epoch 870/1500
#  - 1s - loss: 0.0982 - val_loss: 0.1140
# Epoch 871/1500
#  - 1s - loss: 0.0979 - val_loss: 0.1138
# Epoch 872/1500
#  - 1s - loss: 0.0980 - val_loss: 0.1155
# Epoch 873/1500
#  - 1s - loss: 0.0983 - val_loss: 0.1139
# Epoch 874/1500
# ...
#  - 1s - loss: 0.0935 - val_loss: 0.1131
# Epoch 1216/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1130
# Epoch 1217/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1123
# Epoch 1218/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1133
# Epoch 1219/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1130
# Epoch 1220/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1122
# Epoch 1221/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1124
# Epoch 1222/1500
#  - 1s - loss: 0.0943 - val_loss: 0.1129
# Epoch 1223/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1134
# Epoch 1224/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1132
# Epoch 1225/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1123
# Epoch 1226/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1128
# Epoch 1227/1500
#  - 1s - loss: 0.0947 - val_loss: 0.1129
# Epoch 1228/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1155
# Epoch 1229/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1130
# Epoch 1230/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1135
# Epoch 1231/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1136
# Epoch 1232/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1129
# Epoch 1233/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1122
# Epoch 1234/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1126
# Epoch 1235/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1123
# Epoch 1236/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1124
# Epoch 1237/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1125
# Epoch 1238/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1129
# Epoch 1239/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1123
# Epoch 1240/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1127
# Epoch 1241/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1125
# Epoch 1242/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1125
# Epoch 1243/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1117
# Epoch 1244/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1128
# Epoch 1245/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1139
# Epoch 1246/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1129
# Epoch 1247/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1134
# Epoch 1248/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1113
# Epoch 1249/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1130
# Epoch 1250/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1130
# Epoch 1251/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1133
# Epoch 1252/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1133
# Epoch 1253/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1126
# Epoch 1254/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1140
# Epoch 1255/1500
#  - 1s - loss: 0.0946 - val_loss: 0.1135
# Epoch 1256/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1145
# Epoch 1257/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1127
# Epoch 1258/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1130
# Epoch 1259/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1135
# Epoch 1260/1500
#  - 1s - loss: 0.0943 - val_loss: 0.1129
# Epoch 1261/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1113
# Epoch 1262/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1137
# Epoch 1263/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1125
# Epoch 1264/1500
#  - 1s - loss: 0.0947 - val_loss: 0.1112
# Epoch 1265/1500
#  - 1s - loss: 0.0944 - val_loss: 0.1131
# Epoch 1266/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1116
# Epoch 1267/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1120
# Epoch 1268/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1124
# Epoch 1269/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1119
# Epoch 1270/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1120
# Epoch 1271/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1118
# Epoch 1272/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1148
# Epoch 1273/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1134
# Epoch 1274/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1124
# Epoch 1275/1500
#  - 1s - loss: 0.0940 - val_loss: 0.1133
# Epoch 1276/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1122
# Epoch 1277/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1125
# Epoch 1278/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1134
# Epoch 1279/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1138
# Epoch 1280/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1131
# Epoch 1281/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1130
# Epoch 1282/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1140
# Epoch 1283/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1127
# Epoch 1284/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1131
# Epoch 1285/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1127
# Epoch 1286/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1137
# Epoch 1287/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1121
# Epoch 1288/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1127
# Epoch 1289/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1129
# Epoch 1290/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1139
# Epoch 1291/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1127
# Epoch 1292/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1138
# Epoch 1293/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1122
# Epoch 1294/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1134
# Epoch 1295/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1127
# Epoch 1296/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1120
# Epoch 1297/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1128
# Epoch 1298/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1116
# Epoch 1299/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1144
# Epoch 1300/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1105
# Epoch 1301/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1140
# Epoch 1302/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1130
# Epoch 1303/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1134
# Epoch 1304/1500
#  - 1s - loss: 0.0941 - val_loss: 0.1174
# Epoch 1305/1500
#  - 1s - loss: 0.0942 - val_loss: 0.1127
# Epoch 1306/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1117
# Epoch 1307/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1131
# Epoch 1308/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1120
# Epoch 1309/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1120
# Epoch 1310/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1123
# Epoch 1311/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1132
# Epoch 1312/1500
#  - 1s - loss: 0.0938 - val_loss: 0.1129
# Epoch 1313/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1123
# Epoch 1314/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1126
# Epoch 1315/1500
#  - 1s - loss: 0.0937 - val_loss: 0.1117
# Epoch 1316/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1132
# Epoch 1317/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1117
# Epoch 1318/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1125
# Epoch 1319/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1119
# Epoch 1320/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1121
# Epoch 1321/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1120
# Epoch 1322/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1116
# Epoch 1323/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1126
# Epoch 1324/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1119
# Epoch 1325/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1122
# Epoch 1326/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1115
# Epoch 1327/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1126
# Epoch 1328/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1118
# Epoch 1329/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1127
# Epoch 1330/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1123
# Epoch 1331/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1124
# Epoch 1332/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1125
# Epoch 1333/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1131
# Epoch 1334/1500
#  - 1s - loss: 0.0939 - val_loss: 0.1121
# Epoch 1335/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1120
# Epoch 1336/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1136
# Epoch 1337/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1114
# Epoch 1338/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1128
# Epoch 1339/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1116
# Epoch 1340/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1115
# Epoch 1341/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1139
# Epoch 1342/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1128
# Epoch 1343/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1136
# Epoch 1344/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1132
# Epoch 1345/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1133
# Epoch 1346/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1123
# Epoch 1347/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1131
# Epoch 1348/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1118
# Epoch 1349/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1127
# Epoch 1350/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1128
# Epoch 1351/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1128
# Epoch 1352/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1132
# Epoch 1353/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1127
# Epoch 1354/1500
#  - 1s - loss: 0.0936 - val_loss: 0.1146
# Epoch 1355/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1138
# Epoch 1356/1500
#  - 1s - loss: 0.0935 - val_loss: 0.1129
# Epoch 1357/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1125
# Epoch 1358/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1128
# Epoch 1359/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1124
# Epoch 1360/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1134
# Epoch 1361/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1122
# Epoch 1362/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1139
# Epoch 1363/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1122
# Epoch 1364/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1124
# Epoch 1365/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1124
# Epoch 1366/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1148
# Epoch 1367/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1124
# Epoch 1368/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1136
# Epoch 1369/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1128
# Epoch 1370/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1133
# Epoch 1371/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1132
# Epoch 1372/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1125
# Epoch 1373/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1123
# Epoch 1374/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1112
# Epoch 1375/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1128
# Epoch 1376/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1117
# Epoch 1377/1500
#  - 1s - loss: 0.0934 - val_loss: 0.1126
# Epoch 1378/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1128
# Epoch 1379/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1132
# Epoch 1380/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1125
# Epoch 1381/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1129
# Epoch 1382/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1134
# Epoch 1383/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1134
# Epoch 1384/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1130
# Epoch 1385/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1121
# Epoch 1386/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1115
# Epoch 1387/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1140
# Epoch 1388/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1119
# Epoch 1389/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1124
# Epoch 1390/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1133
# Epoch 1391/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1128
# Epoch 1392/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1134
# Epoch 1393/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1128
# Epoch 1394/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1122
# Epoch 1395/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1135
# Epoch 1396/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1119
# Epoch 1397/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1126
# Epoch 1398/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1121
# Epoch 1399/1500
#  - 1s - loss: 0.0931 - val_loss: 0.1118
# Epoch 1400/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1111
# Epoch 1401/1500
#  - 1s - loss: 0.0932 - val_loss: 0.1123
# Epoch 1402/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1119
# Epoch 1403/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1121
# Epoch 1404/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1115
# Epoch 1405/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1122
# Epoch 1406/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1124
# Epoch 1407/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1128
# Epoch 1408/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1124
# Epoch 1409/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1140
# Epoch 1410/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1122
# Epoch 1411/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1135
# Epoch 1412/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1119
# Epoch 1413/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1125
# Epoch 1414/1500
#  - 2s - loss: 0.0921 - val_loss: 0.1121
# Epoch 1415/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1120
# Epoch 1416/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1137
# Epoch 1417/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1124
# Epoch 1418/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1126
# Epoch 1419/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1132
# Epoch 1420/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1132
# Epoch 1421/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1124
# Epoch 1422/1500
#  - 1s - loss: 0.0930 - val_loss: 0.1142
# Epoch 1423/1500
#  - 1s - loss: 0.0933 - val_loss: 0.1117
# Epoch 1424/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1132
# Epoch 1425/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1116
# Epoch 1426/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1125
# Epoch 1427/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1117
# Epoch 1428/1500
#  - 1s - loss: 0.0919 - val_loss: 0.1119
# Epoch 1429/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1121
# Epoch 1430/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1126
# Epoch 1431/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1121
# Epoch 1432/1500
#  - 1s - loss: 0.0918 - val_loss: 0.1127
# Epoch 1433/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1107
# Epoch 1434/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1134
# Epoch 1435/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1119
# Epoch 1436/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1127
# Epoch 1437/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1123
# Epoch 1438/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1127
# Epoch 1439/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1120
# Epoch 1440/1500
#  - 1s - loss: 0.0929 - val_loss: 0.1117
# Epoch 1441/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1130
# Epoch 1442/1500
#  - 2s - loss: 0.0920 - val_loss: 0.1120
# Epoch 1443/1500
#  - 2s - loss: 0.0919 - val_loss: 0.1125
# Epoch 1444/1500
#  - 2s - loss: 0.0920 - val_loss: 0.1133
# Epoch 1445/1500
#  - 2s - loss: 0.0927 - val_loss: 0.1116
# Epoch 1446/1500
#  - 2s - loss: 0.0929 - val_loss: 0.1137
# Epoch 1447/1500
#  - 2s - loss: 0.0922 - val_loss: 0.1117
# Epoch 1448/1500
#  - 2s - loss: 0.0927 - val_loss: 0.1138
# Epoch 1449/1500
#  - 2s - loss: 0.0926 - val_loss: 0.1118
# Epoch 1450/1500
#  - 1s - loss: 0.0918 - val_loss: 0.1131
# Epoch 1451/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1124
# Epoch 1452/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1121
# Epoch 1453/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1138
# Epoch 1454/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1128
# Epoch 1455/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1140
# Epoch 1456/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1121
# Epoch 1457/1500
#  - 1s - loss: 0.0928 - val_loss: 0.1117
# Epoch 1458/1500
#  - 1s - loss: 0.0919 - val_loss: 0.1119
# Epoch 1459/1500
#  - 1s - loss: 0.0917 - val_loss: 0.1127
# Epoch 1460/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1127
# Epoch 1461/1500
#  - 1s - loss: 0.0920 - val_loss: 0.1113
# Epoch 1462/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1119
# Epoch 1463/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1124
# Epoch 1464/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1120
# Epoch 1465/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1127
# Epoch 1466/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1123
# Epoch 1467/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1122
# Epoch 1468/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1122
# Epoch 1469/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1130
# Epoch 1470/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1123
# Epoch 1471/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1125
# Epoch 1472/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1119
# Epoch 1473/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1112
# Epoch 1474/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1129
# Epoch 1475/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1126
# Epoch 1476/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1125
# Epoch 1477/1500
#  - 1s - loss: 0.0925 - val_loss: 0.1117
# Epoch 1478/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1135
# Epoch 1479/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1114
# Epoch 1480/1500
#  - 1s - loss: 0.0920 - val_loss: 0.1141
# Epoch 1481/1500
#  - 1s - loss: 0.0916 - val_loss: 0.1122
# Epoch 1482/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1121
# Epoch 1483/1500
#  - 1s - loss: 0.0917 - val_loss: 0.1132
# Epoch 1484/1500
#  - 1s - loss: 0.0915 - val_loss: 0.1128
# Epoch 1485/1500
#  - 1s - loss: 0.0919 - val_loss: 0.1121
# Epoch 1486/1500
#  - 1s - loss: 0.0926 - val_loss: 0.1133
# Epoch 1487/1500
#  - 1s - loss: 0.0923 - val_loss: 0.1120
# Epoch 1488/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1122
# Epoch 1489/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1134
# Epoch 1490/1500
#  - 1s - loss: 0.0927 - val_loss: 0.1120
# Epoch 1491/1500
#  - 1s - loss: 0.0919 - val_loss: 0.1138
# Epoch 1492/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1128
# Epoch 1493/1500
#  - 1s - loss: 0.0924 - val_loss: 0.1125
# Epoch 1494/1500
#  - 1s - loss: 0.0917 - val_loss: 0.1125
# Epoch 1495/1500
#  - 1s - loss: 0.0920 - val_loss: 0.1125
# Epoch 1496/1500
#  - 1s - loss: 0.0918 - val_loss: 0.1132
# Epoch 1497/1500
#  - 1s - loss: 0.0920 - val_loss: 0.1119
# Epoch 1498/1500
#  - 1s - loss: 0.0921 - val_loss: 0.1130
# Epoch 1499/1500
#  - 1s - loss: 0.0922 - val_loss: 0.1128
# Epoch 1500/1500
#  - 1s - loss: 0.0917 - val_loss: 0.1121

# %%
# plot history
pyplot.plot(history.history['loss'], label='train-RMSE')
pyplot.plot(history.history['val_loss'], label='test-RMSE')
pyplot.title("QoS attributes prediction of cloud services ")
pyplot.legend()
pyplot.show()

# %%
from math import sqrt
# make a prediction
yhat = model.predict(test_X)
#test_X = test_X.reshape((test_X.shape[0], test_X.shape[1]*test_X.shape[2]))

# %%
# invert scaling for forecast
#20/5=4

inv_yhat1 = scaler.inverse_transform(yhat[:,0:5])
inv_yhat2 = scaler.inverse_transform(yhat[:,5:10])
inv_yhat3 = scaler.inverse_transform(yhat[:,10:15])
inv_yhat4 = scaler.inverse_transform(yhat[:,15:20])
inv_yhat = concatenate((inv_yhat1,inv_yhat2 ), axis=1)
inv_yhat = concatenate((inv_yhat,inv_yhat3 ), axis=1)
inv_yhat = concatenate((inv_yhat,inv_yhat4 ), axis=1)
# invert scaling for actual
#test_y = test_y.reshape((len(test_y), 1))
inv_y1 = scaler.inverse_transform(test_y[:,0:5])
inv_y2 = scaler.inverse_transform(test_y[:,5:10])
inv_y3 = scaler.inverse_transform(test_y[:,10:15])
inv_y4 = scaler.inverse_transform(test_y[:,15:20])
inv_y = concatenate((inv_y1,inv_y2 ), axis=1)
inv_y = concatenate((inv_y,inv_y3 ), axis=1)
inv_y = concatenate((inv_y,inv_y4 ), axis=1)

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1864.905

# %%
# plot history
pyplot.plot(inv_y[:60,5], label='actual value')
pyplot.plot(inv_yhat[:60,5], label='predict value')
pyplot.title("QoS[AV(t+1)]-cloud services prediction")
pyplot.legend()
pyplot.show()

# %%
# plot history
pyplot.plot(inv_y[:60,19], label='actual value')
pyplot.plot(inv_yhat[:60,19], label='predict value')
pyplot.title("QoS[Th(t+3)]-cloud services prediction")
pyplot.legend()
pyplot.show()

# %%
results=[]
for i in range(20):
    results.append(sqrt(mean_squared_error(inv_y[:,i], inv_yhat[:,i])))

# %%
QoS_names=['Av','Mx_rt','Mn_rt','Avg_rt','th']
QoS=[]
QoS_total=[]
for i in range(4):
    QoS=results[i*5:i*5+5]
    QoS_total.append(QoS)
QoS_total=DataFrame(QoS_total)
QoS_total.columns=QoS_names
print(QoS_total)
QoS_total.boxplot()
# Out:
#           Av        Mx_rt       Mn_rt     Avg_rt        th
# 0  13.548300  4150.359262  215.614674  45.376033  0.765965
# 1  12.660985  4689.042546  210.878140  42.805885  0.729229
# 2  17.276257  3507.343724  158.771615  46.519357  0.783163
# 3  18.408249  4228.260399  200.133188  44.019426  0.745508

# %%
# predicted values for each provider
preprocessed_data=[]
for i in range(len(data)):
    values = data[i].values
    values = values.astype('float32')
# normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    scaled=DataFrame(scaled)
    reframed = series_to_supervised(scaled[15:28],12, 0)
    #
    #
    preprocessed_data.append(reframed)

# %%
#export predicted values for each provider
predicted_data=[]
for i in range(len(preprocessed_data)):
    temp=numpy.array( preprocessed_data[i])
    temp=temp.reshape((temp.shape[0], 12, 5))
    predict_QoS_Pi=model.predict(temp)
    predict_QoS_Pi=predict_QoS_Pi.reshape(4,5)
    predicted_data.append(predict_QoS_Pi)                #(predicted_data[0][0,0:3])
    df_temp=DataFrame(predict_QoS_Pi)
    df_temp.to_csv('csv_predictions/'+names[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-299-9150e43bd912> in <module>()
#       8     predicted_data.append(predict_QoS_Pi)                #(predicted_data[0][0,0:3])
#       9     df_temp=DataFrame(predict_QoS_Pi)
# ---> 10     df_temp.to_csv('csv_predictions/'+names[i])
#
# IndexError: list index out of range

# %%
for i in range(len(preprocessed_data)):
    print(names[i])
# Out:
# Av
# Mx_rt
# Mn_rt
# Avg_rt
# th
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-300-4fab2b5b55d8> in <module>()
#       1 for i in range(len(preprocessed_data)):
# ----> 2     print(names[i])
#
# IndexError: list index out of range
