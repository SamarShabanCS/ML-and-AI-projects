# %%
#import libraries
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import matplotlib
from matplotlib import pyplot
# %matplotlib inline
import numpy
# Out:
# Using TensorFlow backend.

# %%
import glob
from keras.layers import Dropout

# %%
df=read_csv('behavior.csv')
df=DataFrame(df)
df
# Out:
#       Unnamed: 0        Av        Rt        Th      Cost
# 0     2014-11-12  0.842818  0.298058  0.696617  0.664014
# 1     2014-11-13  0.847472  0.313881  0.634435  0.752660
# 2     2014-11-14  0.827666  0.292540  0.639504  0.536273
# 3     2014-11-15  0.865894  0.197158  0.661322  0.785753
# 4     2014-11-16  0.877971  0.159817  0.660387  0.675462
# 5     2014-11-17  0.868212  0.311304  0.641472  0.570454
# 6     2014-11-18  0.901666  0.224361  0.626482  0.710291
# 7     2014-11-19  0.863542  0.262821  0.620612  0.641154
# 8     2014-11-20  0.780446  0.284540  0.604847  0.694305
# 9     2014-11-21  0.844473  0.216095  0.674270  0.706597
# 10    2014-11-22  0.855523  0.217811  0.698061  0.632494
# 11    2014-11-23  0.893672  0.203923  0.691153  0.644432
# 12    2014-11-24  0.925544  0.283479  0.656693  0.614856
# 13    2014-11-25  0.855993  0.210542  0.647996  0.642292
# 14    2014-11-26  0.866843  0.219343  0.678312  0.630554
# 15    2014-11-27  0.872926  0.319802  0.688392  0.581148
# 16    2014-11-28  0.903176  0.322387  0.657991  0.599152
# 17    2014-11-29  0.825018  0.316662  0.664004  0.601861
# 18    2014-11-30  0.805965  0.200823  0.677403  0.562701
# 19    2014-12-01  0.841917  0.251446  0.677016  0.645036
# 20    2014-12-02  0.841477  0.315411  0.676755  0.608659
# 21    2014-12-03  0.886936  0.233991  0.679954  0.635774
# 22    2014-12-04  0.778906  0.403390  0.693778  0.644366
# 23    2014-12-05  0.814829  0.327071  0.759266  0.642952
# 24    2014-12-06  0.879376  0.299621  0.714465  0.698860
# 25    2014-12-07  0.914860  0.306013  0.635772  0.713790
# 26    2014-12-08  0.751330  0.358441  0.732918  0.791106
# 27    2014-12-09  0.895612  0.337948  0.699452  0.672267
# 28    2014-12-10  0.829268  0.414900  0.725187  0.679837
# 29    2014-12-11  0.853553  0.334010  0.677135  0.583410
# ...          ...       ...       ...       ...       ...
# 1410  2018-09-22  0.769792  0.474521  0.848703  0.613937
# 1411  2018-09-23  0.800734  0.414001  0.839886  0.734378
# 1412  2018-09-24  0.783014  0.445715  0.865885  0.713647
# 1413  2018-09-25  0.846602  0.581652  0.817570  0.708827
# 1414  2018-09-26  0.809609  0.398838  0.818925  0.752532
# 1415  2018-09-27  0.823835  0.384700  0.855311  0.682480
# 1416  2018-09-28  0.840647  0.514129  0.794173  0.674944
# 1417  2018-09-29  0.778854  0.569405  0.837170  0.782868
# 1418  2018-09-30  0.826210  0.441039  0.891394  0.811429
# 1419  2018-10-01  0.847886  0.515222  0.869343  0.485885
# 1420  2018-10-02  0.817045  0.519714  0.861929  0.693836
# 1421  2018-10-03  0.853444  0.451711  0.879072  0.633583
# 1422  2018-10-04  0.760630  0.567048  0.856222  0.711448
# 1423  2018-10-05  0.862955  0.521612  0.831283  0.718784
# 1424  2018-10-06  0.811304  0.440247  0.846308  0.653077
# 1425  2018-10-07  0.817027  0.460674  0.880514  0.639196
# 1426  2018-10-08  0.845435  0.555070  0.866869  0.575809
# 1427  2018-10-09  0.889840  0.379461  0.883155  0.601171
# 1428  2018-10-10  0.881222  0.462070  0.867042  0.684937
# 1429  2018-10-11  0.855025  0.549031  0.889797  0.701609
# 1430  2018-10-12  0.842743  0.472182  0.875114  0.689380
# 1431  2018-10-13  0.802973  0.524931  0.926822  0.593294
# 1432  2018-10-14  0.871531  0.655183  0.903884  0.695609
# 1433  2018-10-15  0.901540  0.524653  0.921427  0.698317
# 1434  2018-10-16  0.888024  0.587078  0.913700  0.703930
# 1435  2018-10-17  0.761773  0.557654  0.901510  0.555375
# 1436  2018-10-18  0.909996  0.528461  0.885343  0.671011
# 1437  2018-10-19  0.803475  0.652347  0.820083  0.530508
# 1438  2018-10-20  0.847283  0.620483  0.892188  0.606343
# 1439  2018-10-21  0.971091  0.649963  0.855507  0.603541
#
# [1440 rows x 5 columns]

# %%
df.drop(df.columns[[0,4]],axis=1,inplace=True)
df
# Out:
#             Av        Rt        Th
# 0     0.842818  0.298058  0.696617
# 1     0.847472  0.313881  0.634435
# 2     0.827666  0.292540  0.639504
# 3     0.865894  0.197158  0.661322
# 4     0.877971  0.159817  0.660387
# 5     0.868212  0.311304  0.641472
# 6     0.901666  0.224361  0.626482
# 7     0.863542  0.262821  0.620612
# 8     0.780446  0.284540  0.604847
# 9     0.844473  0.216095  0.674270
# 10    0.855523  0.217811  0.698061
# 11    0.893672  0.203923  0.691153
# 12    0.925544  0.283479  0.656693
# 13    0.855993  0.210542  0.647996
# 14    0.866843  0.219343  0.678312
# 15    0.872926  0.319802  0.688392
# 16    0.903176  0.322387  0.657991
# 17    0.825018  0.316662  0.664004
# 18    0.805965  0.200823  0.677403
# 19    0.841917  0.251446  0.677016
# 20    0.841477  0.315411  0.676755
# 21    0.886936  0.233991  0.679954
# 22    0.778906  0.403390  0.693778
# 23    0.814829  0.327071  0.759266
# 24    0.879376  0.299621  0.714465
# 25    0.914860  0.306013  0.635772
# 26    0.751330  0.358441  0.732918
# 27    0.895612  0.337948  0.699452
# 28    0.829268  0.414900  0.725187
# 29    0.853553  0.334010  0.677135
# ...        ...       ...       ...
# 1410  0.769792  0.474521  0.848703
# 1411  0.800734  0.414001  0.839886
# 1412  0.783014  0.445715  0.865885
# 1413  0.846602  0.581652  0.817570
# 1414  0.809609  0.398838  0.818925
# 1415  0.823835  0.384700  0.855311
# 1416  0.840647  0.514129  0.794173
# 1417  0.778854  0.569405  0.837170
# 1418  0.826210  0.441039  0.891394
# 1419  0.847886  0.515222  0.869343
# 1420  0.817045  0.519714  0.861929
# 1421  0.853444  0.451711  0.879072
# 1422  0.760630  0.567048  0.856222
# 1423  0.862955  0.521612  0.831283
# 1424  0.811304  0.440247  0.846308
# 1425  0.817027  0.460674  0.880514
# 1426  0.845435  0.555070  0.866869
# 1427  0.889840  0.379461  0.883155
# 1428  0.881222  0.462070  0.867042
# 1429  0.855025  0.549031  0.889797
# 1430  0.842743  0.472182  0.875114
# 1431  0.802973  0.524931  0.926822
# 1432  0.871531  0.655183  0.903884
# 1433  0.901540  0.524653  0.921427
# 1434  0.888024  0.587078  0.913700
# 1435  0.761773  0.557654  0.901510
# 1436  0.909996  0.528461  0.885343
# 1437  0.803475  0.652347  0.820083
# 1438  0.847283  0.620483  0.892188
# 1439  0.971091  0.649963  0.855507
#
# [1440 rows x 3 columns]

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    #n_in number of lag observations
    #n_out number of next observations
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import LabelEncoder
from numpy import concatenate
#from pandas import DataFrame
#from pandas import concat
#encoder =LabelEncoder()
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
values = df.values
    # integer encode direction
    #encoder = LabelEncoder()
    #values[:,4] = encoder.fit_transform(values[:,4])
    # ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
#reframed = series_to_supervised(scaled, 8, 4)
# frame as supervised learning
reframed = series_to_supervised(scaled, 12, 4)
# drop columns we don't want to predict
#reframed.drop(reframed.columns[[5,6,7,8]], axis=1, inplace=True)
print(reframed.shape)
print(reframed.head())
# drop columns we don't want to predict
# Out:
# (1425, 48)
#     var1(t-12)  var2(t-12)  var3(t-12)  var1(t-11)  var2(t-11)  var3(t-11)  \
# 12    0.842818    0.298058    0.696617    0.847472    0.313881    0.634435
# 13    0.847472    0.313881    0.634435    0.827666    0.292540    0.639504
# 14    0.827666    0.292540    0.639504    0.865894    0.197158    0.661322
# 15    0.865894    0.197158    0.661322    0.877971    0.159817    0.660387
# 16    0.877971    0.159817    0.660387    0.868212    0.311304    0.641472
#
#     var1(t-10)  var2(t-10)  var3(t-10)  var1(t-9)    ...       var3(t)  \
# 12    0.827666    0.292540    0.639504   0.865894    ...      0.656693
# 13    0.865894    0.197158    0.661322   0.877971    ...      0.647996
# 14    0.877971    0.159817    0.660387   0.868212    ...      0.678312
# 15    0.868212    0.311304    0.641472   0.901666    ...      0.688392
# 16    0.901666    0.224361    0.626482   0.863542    ...      0.657991
#
#     var1(t+1)  var2(t+1)  var3(t+1)  var1(t+2)  var2(t+2)  var3(t+2)  \
# 12   0.855993   0.210542   0.647996   0.866843   0.219343   0.678312
# 13   0.866843   0.219343   0.678312   0.872926   0.319802   0.688392
# 14   0.872926   0.319802   0.688392   0.903176   0.322387   0.657991
# 15   0.903176   0.322387   0.657991   0.825018   0.316662   0.664004
# 16   0.825018   0.316662   0.664004   0.805965   0.200823   0.677403
#
#     var1(t+3)  var2(t+3)  var3(t+3)
# 12   0.872926   0.319802   0.688392
# 13   0.903176   0.322387   0.657991
# 14   0.825018   0.316662   0.664004
# 15   0.805965   0.200823   0.677403
# 16   0.841917   0.251446   0.677016
#
# [5 rows x 48 columns]

# %%
flatten_data=numpy.array(reframed)

# %%
print(flatten_data.shape)
# Out:
# (1425, 48)

# %%
# split into train and test sets 80%
train = flatten_data[:1140,:]
test = flatten_data[1140:,:]
# split into input and outputs
train_X, train_y = train[:, :36], train[:,36:]
test_X, test_y = test[:, :36], test[:,36:]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 12, 3))
test_X = test_X.reshape((test_X.shape[0], 12, 3))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1140, 12, 3) (1140, 12) (285, 12, 3) (285, 12)

# %%
from keras import regularizers

# %%
# design network
model = Sequential()
model.add(LSTM(60, input_shape=(train_X.shape[1], train_X.shape[2]))) #,return_sequences=True
model.add(Dropout(0.7))
#model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dropout(0.7))
model.add(Dense(12))#,activation="relu",activity_regularizer=regularizers.l1(0.01)
model.compile(loss='mse', optimizer='adam')  #'mae mse
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 60)                15360
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                732
# =================================================================
# Total params: 16,092
# Trainable params: 16,092
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=150, batch_size=2, validation_data=(test_X, test_y), verbose=2, shuffle=True)
# Out:
# Train on 1140 samples, validate on 285 samples
# Epoch 1/150
#  - 15s - loss: 0.0675 - val_loss: 0.0048
# Epoch 2/150
#  - 9s - loss: 0.0243 - val_loss: 0.0053
# Epoch 3/150
#  - 9s - loss: 0.0177 - val_loss: 0.0039
# Epoch 4/150
#  - 9s - loss: 0.0138 - val_loss: 0.0036
# Epoch 5/150
#  - 10s - loss: 0.0114 - val_loss: 0.0034
# Epoch 6/150
#  - 9s - loss: 0.0097 - val_loss: 0.0037
# Epoch 7/150
#  - 10s - loss: 0.0091 - val_loss: 0.0036
# Epoch 8/150
#  - 9s - loss: 0.0088 - val_loss: 0.0034
# Epoch 9/150
#  - 10s - loss: 0.0085 - val_loss: 0.0032
# Epoch 10/150
#  - 9s - loss: 0.0088 - val_loss: 0.0042
# Epoch 11/150
#  - 11s - loss: 0.0085 - val_loss: 0.0033
# Epoch 12/150
#  - 12s - loss: 0.0087 - val_loss: 0.0035
# Epoch 13/150
#  - 9s - loss: 0.0088 - val_loss: 0.0034
# Epoch 14/150
#  - 9s - loss: 0.0084 - val_loss: 0.0033
# Epoch 15/150
#  - 9s - loss: 0.0084 - val_loss: 0.0033
# Epoch 16/150
#  - 9s - loss: 0.0084 - val_loss: 0.0033
# Epoch 17/150
#  - 9s - loss: 0.0081 - val_loss: 0.0038
# Epoch 18/150
#  - 9s - loss: 0.0084 - val_loss: 0.0033
# Epoch 19/150
#  - 9s - loss: 0.0085 - val_loss: 0.0032
# Epoch 20/150
#  - 9s - loss: 0.0084 - val_loss: 0.0033
# Epoch 21/150
#  - 9s - loss: 0.0082 - val_loss: 0.0033
# Epoch 22/150
#  - 9s - loss: 0.0082 - val_loss: 0.0033
# Epoch 23/150
#  - 9s - loss: 0.0083 - val_loss: 0.0034
# Epoch 24/150
#  - 9s - loss: 0.0078 - val_loss: 0.0032
# Epoch 25/150
#  - 9s - loss: 0.0079 - val_loss: 0.0034
# Epoch 26/150
#  - 9s - loss: 0.0081 - val_loss: 0.0035
# Epoch 27/150
#  - 9s - loss: 0.0085 - val_loss: 0.0031
# Epoch 28/150
#  - 11s - loss: 0.0081 - val_loss: 0.0034
# Epoch 29/150
#  - 10s - loss: 0.0083 - val_loss: 0.0036
# Epoch 30/150
#  - 10s - loss: 0.0081 - val_loss: 0.0034
# Epoch 31/150
#  - 9s - loss: 0.0080 - val_loss: 0.0031
# Epoch 32/150
#  - 9s - loss: 0.0081 - val_loss: 0.0036
# Epoch 33/150
#  - 9s - loss: 0.0081 - val_loss: 0.0033
# Epoch 34/150
#  - 9s - loss: 0.0080 - val_loss: 0.0037
# Epoch 35/150
#  - 9s - loss: 0.0081 - val_loss: 0.0034
# Epoch 36/150
#  - 9s - loss: 0.0082 - val_loss: 0.0034
# Epoch 37/150
#  - 9s - loss: 0.0082 - val_loss: 0.0033
# Epoch 38/150
#  - 9s - loss: 0.0081 - val_loss: 0.0032
# Epoch 39/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 40/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 41/150
#  - 9s - loss: 0.0081 - val_loss: 0.0033
# Epoch 42/150
#  - 12s - loss: 0.0080 - val_loss: 0.0031
# Epoch 43/150
#  - 13s - loss: 0.0078 - val_loss: 0.0034
# Epoch 44/150
#  - 10s - loss: 0.0079 - val_loss: 0.0033
# Epoch 45/150
#  - 11s - loss: 0.0080 - val_loss: 0.0033
# Epoch 46/150
#  - 10s - loss: 0.0078 - val_loss: 0.0033
# Epoch 47/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 48/150
#  - 11s - loss: 0.0078 - val_loss: 0.0036
# Epoch 49/150
#  - 10s - loss: 0.0084 - val_loss: 0.0034
# Epoch 50/150
#  - 9s - loss: 0.0081 - val_loss: 0.0031
# Epoch 51/150
#  - 10s - loss: 0.0077 - val_loss: 0.0036
# Epoch 52/150
#  - 10s - loss: 0.0080 - val_loss: 0.0031
# Epoch 53/150
#  - 10s - loss: 0.0077 - val_loss: 0.0033
# Epoch 54/150
#  - 9s - loss: 0.0076 - val_loss: 0.0033
# Epoch 55/150
#  - 9s - loss: 0.0082 - val_loss: 0.0036
# Epoch 56/150
#  - 9s - loss: 0.0083 - val_loss: 0.0033
# Epoch 57/150
#  - 9s - loss: 0.0083 - val_loss: 0.0036
# Epoch 58/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 59/150
#  - 9s - loss: 0.0081 - val_loss: 0.0035
# Epoch 60/150
#  - 9s - loss: 0.0081 - val_loss: 0.0036
# Epoch 61/150
#  - 9s - loss: 0.0081 - val_loss: 0.0033
# Epoch 62/150
#  - 9s - loss: 0.0081 - val_loss: 0.0035
# Epoch 63/150
#  - 9s - loss: 0.0078 - val_loss: 0.0032
# Epoch 64/150
#  - 9s - loss: 0.0080 - val_loss: 0.0034
# Epoch 65/150
#  - 9s - loss: 0.0078 - val_loss: 0.0030
# Epoch 66/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 67/150
#  - 9s - loss: 0.0080 - val_loss: 0.0032
# Epoch 68/150
#  - 9s - loss: 0.0079 - val_loss: 0.0034
# Epoch 69/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 70/150
#  - 9s - loss: 0.0078 - val_loss: 0.0033
# Epoch 71/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 72/150
#  - 9s - loss: 0.0079 - val_loss: 0.0030
# Epoch 73/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 74/150
#  - 9s - loss: 0.0078 - val_loss: 0.0032
# Epoch 75/150
#  - 9s - loss: 0.0077 - val_loss: 0.0032
# Epoch 76/150
#  - 9s - loss: 0.0078 - val_loss: 0.0035
# Epoch 77/150
#  - 9s - loss: 0.0078 - val_loss: 0.0031
# Epoch 78/150
#  - 9s - loss: 0.0077 - val_loss: 0.0032
# Epoch 79/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 80/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 81/150
#  - 9s - loss: 0.0078 - val_loss: 0.0032
# Epoch 82/150
#  - 9s - loss: 0.0076 - val_loss: 0.0031
# Epoch 83/150
#  - 10s - loss: 0.0078 - val_loss: 0.0032
# Epoch 84/150
#  - 9s - loss: 0.0081 - val_loss: 0.0034
# Epoch 85/150
#  - 9s - loss: 0.0076 - val_loss: 0.0033
# Epoch 86/150
#  - 10s - loss: 0.0079 - val_loss: 0.0032
# Epoch 87/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 88/150
#  - 10s - loss: 0.0076 - val_loss: 0.0031
# Epoch 89/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 90/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 91/150
#  - 9s - loss: 0.0079 - val_loss: 0.0034
# Epoch 92/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 93/150
#  - 9s - loss: 0.0076 - val_loss: 0.0030
# Epoch 94/150
#  - 9s - loss: 0.0079 - val_loss: 0.0030
# Epoch 95/150
#  - 10s - loss: 0.0079 - val_loss: 0.0031
# Epoch 96/150
#  - 10s - loss: 0.0077 - val_loss: 0.0032
# Epoch 97/150
#  - 9s - loss: 0.0082 - val_loss: 0.0034
# Epoch 98/150
#  - 9s - loss: 0.0082 - val_loss: 0.0031
# Epoch 99/150
#  - 9s - loss: 0.0077 - val_loss: 0.0034
# Epoch 100/150
#  - 10s - loss: 0.0078 - val_loss: 0.0032
# Epoch 101/150
#  - 9s - loss: 0.0078 - val_loss: 0.0031
# Epoch 102/150
#  - 10s - loss: 0.0077 - val_loss: 0.0035
# Epoch 103/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 104/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 105/150
#  - 9s - loss: 0.0078 - val_loss: 0.0031
# Epoch 106/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 107/150
#  - 9s - loss: 0.0077 - val_loss: 0.0035
# Epoch 108/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 109/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 110/150
#  - 9s - loss: 0.0075 - val_loss: 0.0032
# Epoch 111/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 112/150
#  - 9s - loss: 0.0079 - val_loss: 0.0034
# Epoch 113/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 114/150
#  - 9s - loss: 0.0077 - val_loss: 0.0032
# Epoch 115/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 116/150
#  - 9s - loss: 0.0077 - val_loss: 0.0030
# Epoch 117/150
#  - 9s - loss: 0.0080 - val_loss: 0.0032
# Epoch 118/150
#  - 9s - loss: 0.0079 - val_loss: 0.0033
# Epoch 119/150
#  - 10s - loss: 0.0077 - val_loss: 0.0032
# Epoch 120/150
#  - 9s - loss: 0.0076 - val_loss: 0.0031
# Epoch 121/150
#  - 9s - loss: 0.0078 - val_loss: 0.0033
# Epoch 122/150
#  - 9s - loss: 0.0076 - val_loss: 0.0031
# Epoch 123/150
#  - 9s - loss: 0.0075 - val_loss: 0.0033
# Epoch 124/150
#  - 9s - loss: 0.0077 - val_loss: 0.0036
# Epoch 125/150
#  - 10s - loss: 0.0076 - val_loss: 0.0032
# Epoch 126/150
#  - 9s - loss: 0.0080 - val_loss: 0.0032
# Epoch 127/150
#  - 9s - loss: 0.0075 - val_loss: 0.0033
# Epoch 128/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 129/150
#  - 9s - loss: 0.0083 - val_loss: 0.0033
# Epoch 130/150
#  - 9s - loss: 0.0076 - val_loss: 0.0032
# Epoch 131/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 132/150
#  - 10s - loss: 0.0080 - val_loss: 0.0033
# Epoch 133/150
#  - 9s - loss: 0.0075 - val_loss: 0.0032
# Epoch 134/150
#  - 9s - loss: 0.0075 - val_loss: 0.0036
# Epoch 135/150
#  - 10s - loss: 0.0077 - val_loss: 0.0033
# Epoch 136/150
#  - 10s - loss: 0.0077 - val_loss: 0.0029
# Epoch 137/150
#  - 9s - loss: 0.0079 - val_loss: 0.0031
# Epoch 138/150
#  - 9s - loss: 0.0076 - val_loss: 0.0033
# Epoch 139/150
#  - 9s - loss: 0.0078 - val_loss: 0.0030
# Epoch 140/150
#  - 9s - loss: 0.0077 - val_loss: 0.0031
# Epoch 141/150
#  - 9s - loss: 0.0079 - val_loss: 0.0031
# Epoch 142/150
#  - 9s - loss: 0.0078 - val_loss: 0.0032
# Epoch 143/150
#  - 9s - loss: 0.0076 - val_loss: 0.0033
# Epoch 144/150
#  - 9s - loss: 0.0078 - val_loss: 0.0034
# Epoch 145/150
#  - 9s - loss: 0.0076 - val_loss: 0.0030
# Epoch 146/150
#  - 9s - loss: 0.0079 - val_loss: 0.0032
# Epoch 147/150
#  - 9s - loss: 0.0077 - val_loss: 0.0030
# Epoch 148/150
#  - 9s - loss: 0.0077 - val_loss: 0.0032
# Epoch 149/150
#  - 9s - loss: 0.0076 - val_loss: 0.0033
# Epoch 150/150
#  - 9s - loss: 0.0080 - val_loss: 0.0032

# %%
# plot history
pyplot.plot(history.history['loss'], label='train-RMSE')
pyplot.plot(history.history['val_loss'], label='test-RMSE')
pyplot.title("QoS attributes prediction of cloud services ")
pyplot.legend()
pyplot.show()

# %%
from math import sqrt
# make a prediction
yhat = model.predict(test_X)
#test_X = test_X.reshape((test_X.shape[0], test_X.shape[1]*test_X.shape[2]))

# %%
# invert scaling for forecast
#20/5=4

inv_yhat1 = scaler.inverse_transform(yhat[:,0:3])
inv_yhat2 = scaler.inverse_transform(yhat[:,3:6])
inv_yhat3 = scaler.inverse_transform(yhat[:,6:9])
inv_yhat4 = scaler.inverse_transform(yhat[:,9:12])
inv_yhat = concatenate((inv_yhat1,inv_yhat2 ), axis=1)
inv_yhat = concatenate((inv_yhat,inv_yhat3 ), axis=1)
inv_yhat = concatenate((inv_yhat,inv_yhat4 ), axis=1)
# invert scaling for actual
#test_y = test_y.reshape((len(test_y), 1))
inv_y1 = scaler.inverse_transform(test_y[:,0:3])
inv_y2 = scaler.inverse_transform(test_y[:,3:6])
inv_y3 = scaler.inverse_transform(test_y[:,6:9])
inv_y4 = scaler.inverse_transform(test_y[:,9:12])
inv_y = concatenate((inv_y1,inv_y2 ), axis=1)
inv_y = concatenate((inv_y,inv_y3 ), axis=1)
inv_y = concatenate((inv_y,inv_y4 ), axis=1)

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.057

# %%
# plot history
pyplot.plot(inv_y[:,0], label='actual value')
pyplot.plot(inv_yhat[:,0], label='predict value')
pyplot.title("QoS[AV(t+1)]-cloud services prediction")
pyplot.legend()
pyplot.show()

# %%
# plot history
pyplot.plot(inv_y[:,1], label='actual value')
pyplot.plot(inv_yhat[:,1], label='predict value')
pyplot.title("QoS[AV(t+1)]-cloud services prediction")
pyplot.legend()
pyplot.show()

# %%
# plot history
pyplot.plot(inv_y[:,2], label='actual value')
pyplot.plot(inv_yhat[:,2], label='predict value')
pyplot.title("QoS[AV(t+1)]-cloud services prediction")
pyplot.legend()
pyplot.show()

# %%
results=[]
for i in range(12):
    results.append(sqrt(mean_squared_error(inv_y[:,i], inv_yhat[:,i])))

# %%
QoS_names=['Av','Rt','Th']
QoS=[]
QoS_total=[]
for i in range(4):
    QoS=results[i*3:i*3+3]
    QoS_total.append(QoS)
QoS_total=DataFrame(QoS_total)
QoS_total.columns=QoS_names
print(QoS_total)
QoS_total.boxplot()
# Out:
#          Av        Rt        Th
# 0  0.051602  0.066940  0.041169
# 1  0.053211  0.068776  0.042657
# 2  0.052790  0.071075  0.044627
# 3  0.055721  0.072699  0.047841

# %%
# predicted values for each provider
preprocessed_data=[]
for i in range(len(data)):
    values = data[i].values
    values = values.astype('float32')
# normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    scaled=DataFrame(scaled)
    reframed = series_to_supervised(scaled[15:28],12, 0)
    #
    #
    preprocessed_data.append(reframed)

# %%
end_user_future_weights=series_to_supervised(scaled[15:28],12, 0)

# %%
#export predicted values for each provider
predicted_data=[]
for i in range(len(preprocessed_data)):
    temp=numpy.array( preprocessed_data[i])
    temp=temp.reshape((temp.shape[0], 12, 5))
    predict_QoS_Pi=model.predict(temp)
    predict_QoS_Pi=predict_QoS_Pi.reshape(4,5)
    predicted_data.append(predict_QoS_Pi)                #(predicted_data[0][0,0:3])
    df_temp=DataFrame(predict_QoS_Pi)
    df_temp.to_csv('csv_predictions/'+names[i][4:])
